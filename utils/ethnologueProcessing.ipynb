# %% [markdown]
# # **Graph Representation of Ethnologue Language Hierarchy**

# %% [markdown]
# We aim to structure the data in json format such that we have a graph representation resembling the airport data in lab:
#
# ```
# {
#     'nodes' : [
#         {
#             'id': node_index,
#             'name': language_name,
#             'country': country_name,
#             'score': EGIDS_score,
#             'latitude': latitude,
#             'longitude': longitude
#         },
#         ...
#     ],
#
#     'links' : [
#         {
#             'source': parent_classification_index,
#             'target': child_classifcation_index
#         }
#     ]
#
# }
# ```

# %%
import numpy as np
import pandas as pd
import json

# %%
tol_df = pd.read_csv("../data/Table_of_Languages.csv")
tol_df.head()
# Out:
#   ISO_639        Language_Name     Uninverted_Name Country_Code  \
# 0     aaa               Ghotuo              Ghotuo           NG
# 1     aab           Alumu-Tesu          Alumu-Tesu           NG
# 2     aac                  Ari                 Ari           PG
# 3     aad                 Amal                Amal           PG
# 4     aae  Albanian, Arbëreshë  Arbëreshë Albanian           IT
#
#        Country_Name Region_Code      Region_Name     Area  L1_Users  Digits  \
# 0           Nigeria         WAF   Western Africa   Africa    9000.0     4.0
# 1           Nigeria         WAF   Western Africa   Africa    7000.0     4.0
# 2  Papua New Guinea         MEL        Melanesia  Pacific      50.0     2.0
# 3  Papua New Guinea         MEL        Melanesia  Pacific     830.0     3.0
# 4             Italy         SEU  Southern Europe   Europe  100000.0     6.0
#
#    ...  Latitude  Longitude EGIDS Is_Written  Institutional  Developing  \
# 0  ...    7.1154     5.9528    6a          F              0           0
# 1  ...    9.0164     8.6120    6a          F              0           0
# 2  ...   -7.9172   142.3877    6b          T              0           0
# 3  ...   -4.0487   141.9967    6a          F              0           0
# 4  ...   38.8985    16.7019    6b          T              0           0
#
#   Vigorous In_Trouble  Dying  Extinct
# 0        1          0      0        0
# 1        1          0      0        0
# 2        0          1      0        0
# 3        1          0      0        0
# 4        0          1      0        0
#
# [5 rows x 24 columns]

# %%
tol_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7457 entries, 0 to 7456
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ISO_639          7456 non-null   object
#  1   Language_Name    7457 non-null   object
#  2   Uninverted_Name  7457 non-null   object
#  3   Country_Code     7441 non-null   object
#  4   Country_Name     7457 non-null   object
#  5   Region_Code      7457 non-null   object
#  6   Region_Name      7457 non-null   object
#  7   Area             7457 non-null   object
#  8   L1_Users         7248 non-null   float64
#  9   Digits           7248 non-null   float64
#  10  All_Users        7047 non-null   float64
#  11  Countries        7457 non-null   int64
#  12  Family           7457 non-null   object
#  13  Classification   7425 non-null   object
#  14  Latitude         7426 non-null   float64
#  15  Longitude        7426 non-null   float64
#  16  EGIDS            7457 non-null   object
#  17  Is_Written       7457 non-null   object
#  18  Institutional    7457 non-null   int64
#  19  Developing       7457 non-null   int64
#  20  Vigorous         7457 non-null   int64
#  21  In_Trouble       7457 non-null   int64
#  22  Dying            7457 non-null   int64
#  23  Extinct          7457 non-null   int64
# dtypes: float64(5), int64(7), object(12)
# memory usage: 1.4+ MB

# %% [markdown]
# ## **Constructing a Hierarchal Language Tree**

# %%
# lets only deal with non-null classifications (complete cases)
tol_df_cc = tol_df.dropna(axis = 0, how = 'any')
print(tol_df_cc.shape)
# Out:
# (6967, 24)

# %% [markdown]
# Let's also set commas in `Language_Name` to hyphens in order to not mess up our `.split` distinction.

# %%
tol_df_cc['Language_Name'] = tol_df_cc['Language_Name'].str.replace(', ', '-')
tol_df_cc.head()
# Out:
# /var/folders/72/n4_78wjx21b_cl9nv02s1vq00000gn/T/ipykernel_3823/352847003.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tol_df_cc['Language_Name'] = tol_df_cc['Language_Name'].str.replace(', ', '-')
#   ISO_639       Language_Name     Uninverted_Name Country_Code  \
# 0     aaa              Ghotuo              Ghotuo           NG
# 1     aab          Alumu-Tesu          Alumu-Tesu           NG
# 2     aac                 Ari                 Ari           PG
# 3     aad                Amal                Amal           PG
# 4     aae  Albanian-Arbëreshë  Arbëreshë Albanian           IT
#
#        Country_Name Region_Code      Region_Name     Area  L1_Users  Digits  \
# 0           Nigeria         WAF   Western Africa   Africa    9000.0     4.0
# 1           Nigeria         WAF   Western Africa   Africa    7000.0     4.0
# 2  Papua New Guinea         MEL        Melanesia  Pacific      50.0     2.0
# 3  Papua New Guinea         MEL        Melanesia  Pacific     830.0     3.0
# 4             Italy         SEU  Southern Europe   Europe  100000.0     6.0
#
#    ...  Latitude  Longitude EGIDS Is_Written  Institutional  Developing  \
# 0  ...    7.1154     5.9528    6a          F              0           0
# 1  ...    9.0164     8.6120    6a          F              0           0
# 2  ...   -7.9172   142.3877    6b          T              0           0
# 3  ...   -4.0487   141.9967    6a          F              0           0
# 4  ...   38.8985    16.7019    6b          T              0           0
#
#   Vigorous In_Trouble  Dying  Extinct
# 0        1          0      0        0
# 1        1          0      0        0
# 2        0          1      0        0
# 3        1          0      0        0
# 4        0          1      0        0
#
# [5 rows x 24 columns]

# %% [markdown]
# For each group of classification, we take the average longitude/latitude as the rough location (this may or may not be an accurate depiction of the true language origin).

# %%
tol_df_cc['Classification'].unique()
# Out:
# array(['Niger-Congo, Atlantic-Congo, Volta-Congo, Benue-Congo, Edoid, North-Central, Ghotuo-Uneme-Yekhee',
#        'Niger-Congo, Atlantic-Congo, Volta-Congo, Benue-Congo, Plateau, Alumic',
#        'Trans-New Guinea, Gogodala-Suki, Gogodala', ...,
#        'Mixe-Zoquean, Zoquean, Chiapas Zoquean, Northeast Zoque',
#        'Zaparoan, Záparo',
#        'Niger-Congo, Atlantic-Congo, Volta-Congo, Benue-Congo, Bantoid, Southern, Narrow Bantu, Central, S, Nguni (S.42)'],
#       dtype=object)

# %%
# build lon/lat hierarchal dictionary
hier_dict = {}

# build tree to leaf languages
node_index = 0
for row in range(tol_df_cc.shape[0]):
    curr_lang = tol_df_cc.iloc[row]
    classification = curr_lang['Classification']

    # for each row, look at each hierarchal structure
    hierarchy = classification.split(", ") + [curr_lang['Language_Name']]
    for i in range(1, len(hierarchy)+1): # ordered levels split by commas
        subgroup = ", ".join(hierarchy[:i])

        # if we haven't seen a child before, then define a new empty node
        if subgroup not in hier_dict: 
            # define child node
            hier_dict[subgroup] = {
                'subgroups': {}, 
                'name' : "",
                'country': [],
                'latitude': [],
                'longitude': [],
                'id': 0,
                'code': [],
                'score': [],
                'length': i
            }        
            hier_dict[subgroup]['id'] = node_index
            hier_dict[subgroup]['name'] = hierarchy[i-1]
            node_index += 1 # index for every subgroup
        
        # get child node lat/lon for aggregation later
        hier_dict[subgroup]['latitude'].append(curr_lang['Latitude'])
        hier_dict[subgroup]['longitude'].append(curr_lang['Longitude'])
        hier_dict[subgroup]['code'].append(curr_lang['ISO_639']) # language codes
        hier_dict[subgroup]['score'].append(curr_lang['EGIDS']) # egids scores
        hier_dict[subgroup]['country'].append(curr_lang['Country_Name']) # country names
        

print("Total Nodes: ", node_index)
# Out:
# Total Nodes:  10177

# %%
# aggregating node values
for subgroup in hier_dict:
    countries = hier_dict[subgroup]['country']
    scores = hier_dict[subgroup]['score']
    hier_dict[subgroup]['country'] = max(set(countries), key=countries.count)
    hier_dict[subgroup]['score'] = max(set(scores), key=scores.count)
    hier_dict[subgroup]['mean_latitude'] = np.mean(hier_dict[subgroup]['latitude'])
    hier_dict[subgroup]['mean_longitude'] = np.mean(hier_dict[subgroup]['longitude'])

# %% [markdown]
# #### **Building Links**

# %%
# build links
links = []
for subgroup in hier_dict:
    prev_hier_id = -1
    hierarchy = subgroup.split(', ')
    for i in range(1, len(hierarchy)+1): # ordered levels split by commas
        subgroup = ", ".join(hierarchy[:i])
        try: 
            hier_id = hier_dict[subgroup]['id'] 
        except:
            print(subgroup, "\n", hierarchy)
        links.append({
            'source': prev_hier_id,
            'target': hier_id,
            'length': i, # path length
        })
        prev_hier_id = hier_id

# %%
links = sorted(links, key=lambda x: (x['source'], x['target']))
links[:10]
# Out:
# [{'source': -1, 'target': 0, 'length': 1},
#  {'source': -1, 'target': 0, 'length': 1},
#  {'source': -1, 'target': 0, 'length': 1},
#  {'source': -1, 'target': 0, 'length': 1},
#  {'source': -1, 'target': 0, 'length': 1},
#  {'source': -1, 'target': 0, 'length': 1},
#  {'source': -1, 'target': 0, 'length': 1},
#  {'source': -1, 'target': 0, 'length': 1},
#  {'source': -1, 'target': 0, 'length': 1},
#  {'source': -1, 'target': 0, 'length': 1}]

# %%
unique_links = []
for i in range(1, len(links)):
    if links[i] != links[i-1]:
        unique_links.append(links[i])
unique_links[:10]
# Out:
# [{'source': -1, 'target': 11, 'length': 1},
#  {'source': -1, 'target': 15, 'length': 1},
#  {'source': -1, 'target': 18, 'length': 1},
#  {'source': -1, 'target': 22, 'length': 1},
#  {'source': -1, 'target': 29, 'length': 1},
#  {'source': -1, 'target': 36, 'length': 1},
#  {'source': -1, 'target': 51, 'length': 1},
#  {'source': -1, 'target': 59, 'length': 1},
#  {'source': -1, 'target': 69, 'length': 1},
#  {'source': -1, 'target': 116, 'length': 1}]

# %%
print(len(unique_links)) # this will probably be < total nodes since targets may be final nodes (~ 7k languages)
# Out:
# 10176

# %%
a = 0
for i in unique_links:
    if i['length'] > a:
        a = i['length']
print(a)
# Out:
# 15

# %% [markdown]
# #### **Building Nodes**

# %%
nodes = []
for subgroup in hier_dict:

    subgroup_node_data = {
        'id': hier_dict[subgroup]['id'],
        'name': hier_dict[subgroup]['name'],
        'country': hier_dict[subgroup]['country'], # get most freq country from subgroups
        'score': hier_dict[subgroup]['score'], # get most freq scores from subgroups
        'latitude': round(hier_dict[subgroup]['mean_latitude'], 2),
        'longitude': round(hier_dict[subgroup]['mean_longitude'], 2),
        'length': hier_dict[subgroup]['length']
    }
    nodes.append(subgroup_node_data)

# %%
nodes[:10]
# Out:
# [{'id': 0,
#   'name': 'Niger-Congo',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 3.75,
#   'longitude': 12.1,
#   'length': 1},
#  {'id': 1,
#   'name': 'Atlantic-Congo',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 3.31,
#   'longitude': 12.83,
#   'length': 2},
#  {'id': 2,
#   'name': 'Volta-Congo',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 2.91,
#   'longitude': 14.02,
#   'length': 3},
#  {'id': 3,
#   'name': 'Benue-Congo',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 0.74,
#   'longitude': 17.69,
#   'length': 4},
#  {'id': 4,
#   'name': 'Edoid',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 6.6,
#   'longitude': 6.06,
#   'length': 5},
#  {'id': 5,
#   'name': 'North-Central',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 7.0,
#   'longitude': 6.13,
#   'length': 6},
#  {'id': 6,
#   'name': 'Ghotuo-Uneme-Yekhee',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 7.13,
#   'longitude': 6.17,
#   'length': 7},
#  {'id': 7,
#   'name': 'Ghotuo',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 7.12,
#   'longitude': 5.95,
#   'length': 8},
#  {'id': 8,
#   'name': 'Plateau',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 9.43,
#   'longitude': 8.54,
#   'length': 5},
#  {'id': 9,
#   'name': 'Alumic',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 9.02,
#   'longitude': 8.61,
#   'length': 6}]

# %%
min(nodes, key=lambda x : x['score'])
# Out:
# {'id': 2683,
#  'name': 'Chinese-Mandarin',
#  'country': 'China',
#  'score': '0',
#  'latitude': 39.91,
#  'longitude': 116.4,
#  'length': 3}

# %%
max(nodes, key=lambda x : x['score'])
# Out:
# {'id': 126,
#  'name': 'Andamanese',
#  'country': 'India',
#  'score': 'x10',
#  'latitude': 12.33,
#  'longitude': 92.79,
#  'length': 1}

# %% [markdown]
# #### **Making the JSON**

# %%
fin_json = {'nodes': nodes, 'links': unique_links}

# %%
import copy
fin_json_rename = copy.deepcopy(fin_json)

# %%
# renaming EGIDs to human friendly
EGIDS_dict = {
    '0': 'International use (Safe)',
    '1': 'National use (Safe)',
    '2': 'Regionally government/media (Safe_',
    '3': 'Regional trading (Safe)',
    '4': 'Taught throughout education (Safe)',
    '5': 'Written (Safe)',
    '6a': 'Spoken by all generations (Safe)',
    '6b': 'Spoken by all generations (Vulnerable)',
    '7': 'Spoken by parents (Endangered)',
    '8a': 'Spoken by grandparents (Severely Endangered)',
    '8b': 'Spoken by grandparents (Critically Endangered)',
    '9': 'Heritage itentity (Extinct)',
    '10': 'No ethnic identity remains (Extinct)',
    'x10': 'No ethnic identity remains (Extinct)'
}

for dict in fin_json_rename['nodes']:
    dict['score'] = EGIDS_dict[dict['score']]

# %%
with open("../data/ethno_links.json", "w") as outfile:
    json.dump(fin_json_rename, outfile)

# %% [markdown]
# ### **Recursive Mess**

# %%
# build lon/lat hierarchal dictionary
hier_dict = {'Top-Level':{'subgroups': {},
                          'name': [],
                          'country': [],
                          'latitude': [],
                          'longitude': [],
                          'id': -1},
                          'code': [],
                          'score': [],
                          'mean_latitude': 0,
                          'mean_longitude': 0}

# build tree to leaf languages
node_index = 0
for row in range(tol_df_cc.shape[0]):
    curr_lang = tol_df_cc.iloc[row]
    classification = curr_lang['Classification']
    prev_hier_dict = hier_dict['Top-Level']['subgroups']

    # for each row, look at each hierarchal structure
    for subgroup in classification.split(", ") + [curr_lang['Language_Name']]: # ordered levels split by commas

        # if we haven't seen a child before, then define a new empty node
        if subgroup not in prev_hier_dict: 
            # define child node
            prev_hier_dict[subgroup] = {
                'subgroups': {}, 
                'name' : "",
                'country': [],
                'latitude': [],
                'longitude': [],
                'id': 0,
                'code': [],
                'score': [],
            }        
            prev_hier_dict[subgroup]['id'] = node_index
            prev_hier_dict[subgroup]['name'] = subgroup
            node_index += 1 # index for every subgroup
        
        # get child node lat/lon for aggregation later
        prev_hier_dict[subgroup]['latitude'].append(curr_lang['Latitude'])
        prev_hier_dict[subgroup]['longitude'].append(curr_lang['Longitude'])
        prev_hier_dict[subgroup]['code'].append(curr_lang['ISO_639']) # language codes
        prev_hier_dict[subgroup]['score'].append(curr_lang['EGIDS']) # egids scores
        prev_hier_dict[subgroup]['country'].append(curr_lang['Country_Name']) # country names

        # iterative recursion
        prev_hier_dict = prev_hier_dict[subgroup]['subgroups']

print("Total Nodes: ", node_index)
# Out:
# Total Nodes:  10177

# %%
def get_all_keys(d):
    for key, value in d.items():
        yield key
        if isinstance(value, dict):
            yield from get_all_keys(value)

i = 0
for x in get_all_keys(hier_dict):
    i += 1
print(i)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[73], line 8
#       5             yield from get_all_keys(value)
#       7 i = 0
# ----> 8 for x in get_all_keys(hier_dict):
#       9     i += 1
#      10 print(i)
#
# Cell In[73], line 2, in get_all_keys(d)
#       1 def get_all_keys(d):
# ----> 2     for key, value in d['subgroups'].items():
#       3         yield key
#       4         if isinstance(value, dict):
#
# KeyError: 'subgroups'

# %%
sorted(list(hier_dict['Top-Level']['latitude']))
# Out:
# []

# %%
prev_layer = hier_dict['Top-Level']['subgroups']
for subgroup in prev_layer:
    prev_layer[subgroup]['mean_latitude'] = np.mean(prev_layer[subgroup]['latitude'])
    prev_layer[subgroup]['mean_longitude'] = np.mean(prev_layer[subgroup]['longitude'])

# %%
# getting average lat/lon recursively
def aggregate_locations(hier_dict):
    """
    in-place aggregation of locations for every group (currently only mean)
    """

    if not hier_dict['subgroups']:
        # basecase
        hier_dict['mean_latitude'] = hier_dict['latitude'][0]
        hier_dict['mean_longitude'] = hier_dict['longitude'][0]
        return

    for subgroup in dict['subgroups']:
        hier_dict['subgroups'][subgroup]['mean_latitude'] = np.mean(hier_dict['subgroups'][subgroup]['latitude'])
        hier_dict['subgroups'][subgroup]['mean_longitude'] = np.mean(hier_dict['subgroups'][subgroup]['longitude'])
        return aggregate_locations(hier_dict['subgroups'][subgroup])

aggregate_locations(hier_dict['Top-Level'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 18
#      15         hier_dict['subgroups'][subgroup]['mean_longitude'] = np.mean(hier_dict['subgroups'][subgroup]['longitude'])
#      16         return aggregate_locations(hier_dict['subgroups'][subgroup])
# ---> 18 aggregate_locations(hier_dict['Top-Level'])
#
# TypeError: aggregate_locations() takes 0 positional arguments but 1 was given

# %%
hier_dict['Top-Level']['subgroups']['Niger-Congo']['country']
# Out:
# ['Nigeria',
#  'Nigeria',
#  'Côte d’Ivoire',
#  'Cameroon',
#  'Côte d’Ivoire',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Ghana',
#  'Côte d’Ivoire',
#  'Ghana',
#  'Nigeria',
#  'Sudan',
#  'Ghana',
#  'Cameroon',
#  'Togo',
#  'Côte d’Ivoire',
#  'Ghana',
#  'Nigeria',
#  'Cameroon',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Ghana',
#  'Nigeria',
#  'Nigeria',
#  'Democratic Republic of the Congo',
#  'Cameroon',
#  'Cameroon',
#  'Ghana',
#  'Côte d’Ivoire',
#  'Togo',
#  'Côte d’Ivoire',
#  'Nigeria',
#  'Côte d’Ivoire',
#  'Nigeria',
#  'Nigeria',
#  'Central African Republic',
#  'Benin',
#  'Ghana',
#  'Nigeria',
#  'Nigeria',
#  'Ghana',
#  'Togo',
#  'Cameroon',
#  'Congo',
#  'Nigeria',
#  'Côte d’Ivoire',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Ghana',
#  'Nigeria',
#  'Cameroon',
#  'Nigeria',
#  'Côte d’Ivoire',
#  'Mali',
#  'Nigeria',
#  'Tanzania',
#  'Nigeria',
#  'Cameroon',
#  'Cameroon',
#  'Nigeria',
#  'Côte d’Ivoire',
#  'Cameroon',
#  'Benin',
#  'Zambia',
#  'Nigeria',
#  'Côte d’Ivoire',
#  'Ghana',
#  'Nigeria',
#  'Nigeria',
#  'Central African Republic',
#  'Benin',
#  'Nigeria',
#  'Togo',
#  'Nigeria',
#  'Nigeria',
#  'Cameroon',
#  'Guinea-Bissau',
#  'Cameroon',
#  'Cameroon',
#  'Mali',
#  'Cameroon',
#  'Nigeria',
#  'Cameroon',
#  'Cameroon',
#  'Cameroon',
#  'Benin',
#  'Democratic Republic of the Congo',
#  'Gabon',
#  'Cameroon',
#  'Cameroon',
#  'Cameroon',
#  'Democratic Republic of the Congo',
#  'Burkina Faso',
#  'Central African Republic',
#  'Cameroon',
#  'Nigeria',
#  'Cameroon',
#  'Cameroon',
#  'Cameroon',
#  'Senegal',
#  'Cameroon',
#  'Guinea',
#  'Côte d’Ivoire',
#  'Nigeria',
#  'Democratic Republic of the Congo',
#  'Nigeria',
#  'Nigeria',
#  'Senegal',
#  'Senegal',
#  'South Sudan',
#  'Tanzania',
#  'Central African Republic',
#  'Cameroon',
#  'Cameroon',
#  'Cameroon',
#  'Benin',
#  'Zambia',
#  'Congo',
#  'Chad',
#  'Côte d’Ivoire',
#  'Côte d’Ivoire',
#  'Tanzania',
#  'Cameroon',
#  'Central African Republic',
#  'Cameroon',
#  'Central African Republic',
#  'Cameroon',
#  'Burkina Faso',
#  'Cameroon',
#  'Nigeria',
#  'Cameroon',
#  'Cameroon',
#  'Nigeria',
#  'Democratic Republic of the Congo',
#  'Burkina Faso',
#  'Guinea-Bissau',
#  'Nigeria',
#  'Nigeria',
#  'Ghana',
#  'Nigeria',
#  'Democratic Republic of the Congo',
#  'Ghana',
#  'Cameroon',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Guinea-Bissau',
#  'Central African Republic',
#  'Senegal',
#  'Cameroon',
#  'Côte d’Ivoire',
#  'Nigeria',
#  'Cameroon',
#  'Democratic Republic of the Congo',
#  'Central African Republic',
#  'Cameroon',
#  'Central African Republic',
#  'Cameroon',
#  'Cameroon',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Nigeria',
#  'Congo',
#  'Nigeria',
#  'Guinea-Bissau',
#  'Liberia',
#  'Democratic Republic of the Congo',
#  'Benin',
#  'Angola',
#  'Benin',
#  'Nigeria',
#  'Democratic Republic of the Congo',
#  'Guinea',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Cameroon',
#  'Mali',
#  'Cameroon',
#  'Congo',
#  'Equatorial Guinea',
#  'Democratic Republic of the Congo',
#  'Equatorial Guinea',
#  'Democratic Republic of the Congo',
#  'Cameroon',
#  'Cameroon',
#  'Burkina Faso',
#  'Democratic Republic of the Congo',
#  'Congo',
#  'Nigeria',
#  'Mali',
#  'Tanzania',
#  'Ghana',
#  'Burkina Faso',
#  'Central African Republic',
#  'Mali',
#  'Central African Republic',
#  'Democratic Republic of the Congo',
#  'Benin',
#  'Benin',
#  'Guinea',
#  'Togo',
#  'Senegal',
#  'Central African Republic',
#  'Cameroon',
#  'Cameroon',
#  'Nigeria',
#  'Cameroon',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Cameroon',
#  'Democratic Republic of the Congo',
#  'Cameroon',
#  'Botswana',
#  'Democratic Republic of the Congo',
#  'Nigeria',
#  'Senegal',
#  'Cameroon',
#  'Nigeria',
#  'Cameroon',
#  'Nigeria',
#  'Nigeria',
#  'Guinea',
#  'Liberia',
#  'Nigeria',
#  'Cameroon',
#  'Guinea',
#  'Nigeria',
#  'Cameroon',
#  'Côte d’Ivoire',
#  'Nigeria',
#  'Nigeria',
#  'Chad',
#  'Togo',
#  'Democratic Republic of the Congo',
#  'Congo',
#  'Nigeria',
#  'Cameroon',
#  'Sierra Leone',
#  'Nigeria',
#  'Democratic Republic of the Congo',
#  'Gabon',
#  'Sierra Leone',
#  'Nigeria',
#  'Equatorial Guinea',
#  'Cameroon',
#  'South Sudan',
#  'Nigeria',
#  'Cameroon',
#  'Chad',
#  'Congo',
#  'Zambia',
#  'Mozambique',
#  'Cameroon',
#  'Burkina Faso',
#  'Democratic Republic of the Congo',
#  'Burkina Faso',
#  'Democratic Republic of the Congo',
#  'Cameroon',
#  'Ghana',
#  'Democratic Republic of the Congo',
#  'Burkina Faso',
#  'Congo',
#  'Equatorial Guinea',
#  'Kenya',
#  'Burkina Faso',
#  'Cameroon',
#  'Cameroon',
#  'Mali',
#  'Cameroon',
#  'Nigeria',
#  'Nigeria',
#  'Democratic Republic of the Congo',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Cameroon',
#  'Liberia',
#  'Mali',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Cameroon',
#  'Nigeria',
#  'Mali',
#  'Nigeria',
#  'Nigeria',
#  'Senegal',
#  'Benin',
#  'Nigeria',
#  'Nigeria',
#  'Mozambique',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Uganda',
#  'Mozambique',
#  'Benin',
#  'Angola',
#  'Ghana',
#  'Cameroon',
#  'Ghana',
#  'Ghana',
#  'Burkina Faso',
#  'Kenya',
#  'Senegal',
#  'Ghana',
#  'Burkina Faso',
#  'Nigeria',
#  'Senegal',
#  'Cameroon',
#  'Kenya',
#  'Tanzania',
#  'Mozambique',
#  'Tanzania',
#  'Senegal',
#  'Cameroon',
#  'Ghana',
#  'Chad',
#  'Côte d’Ivoire',
#  'Kenya',
#  'Nigeria',
#  'Mali',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Mali',
#  'Mali',
#  'Nigeria',
#  'Mali',
#  'Congo',
#  'Mali',
#  'Liberia',
#  'Nigeria',
#  'Cameroon',
#  'Central African Republic',
#  'Democratic Republic of the Congo',
#  'Ghana',
#  'Mali',
#  'Burkina Faso',
#  'Burkina Faso',
#  'Burkina Faso',
#  'Angola',
#  'Tanzania',
#  'Côte d’Ivoire',
#  'Kenya',
#  'Cameroon',
#  'Nigeria',
#  'Nigeria',
#  'Democratic Republic of the Congo',
#  'Mali',
#  'Gabon',
#  'Mali',
#  'Cameroon',
#  'Cameroon',
#  'Mozambique',
#  'Tanzania',
#  'Côte d’Ivoire',
#  'Burkina Faso',
#  'Tanzania',
#  'Nigeria',
#  'Democratic Republic of the Congo',
#  'Benin',
#  'Burkina Faso',
#  'Cameroon',
#  'Ghana',
#  'Nigeria',
#  'Mali',
#  'Mali',
#  'Mali',
#  'Mali',
#  'Mali',
#  'Mali',
#  'Mali',
#  'Cameroon',
#  'Nigeria',
#  'Kenya',
#  'Cameroon',
#  'Mali',
#  'Burkina Faso',
#  'Côte d’Ivoire',
#  'Mali',
#  'Senegal',
#  'Côte d’Ivoire',
#  'Nigeria',
#  'Democratic Republic of the Congo',
#  'Nigeria',
#  'Congo',
#  'Côte d’Ivoire',
#  'Kenya',
#  'Nigeria',
#  'Nigeria',
#  'Côte d’Ivoire',
#  'Nigeria',
#  'Nigeria',
#  'Guinea-Bissau',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Cameroon',
#  'Mozambique',
#  'Nigeria',
#  'Nigeria',
#  'Sudan',
#  'Nigeria',
#  'Nigeria',
#  'Guinea',
#  'Cameroon',
#  'Nigeria',
#  'Nigeria',
#  'Côte d’Ivoire',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Cameroon',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Ghana',
#  'Cameroon',
#  'Nigeria',
#  'Nigeria',
#  'Cameroon',
#  'Cameroon',
#  'Nigeria',
#  'Equatorial Guinea',
#  'Senegal',
#  'South Sudan',
#  'Mali',
#  'Tanzania',
#  'Nigeria',
#  'Cameroon',
#  'Democratic Republic of the Congo',
#  'Cameroon',
#  'Chad',
#  'Benin',
#  'Democratic Republic of the Congo',
#  'Benin',
#  'Cameroon',
#  'Senegal',
#  'Benin',
#  'Guinea',
#  'Niger',
#  'Chad',
#  'Sudan',
#  'Niger',
#  'Nigeria',
#  'Ghana',
#  'Central African Republic',
#  'Benin',
#  'Liberia',
#  'Central African Republic',
#  'Central African Republic',
#  'Nigeria',
#  'Benin',
#  'Central African Republic',
#  'Benin',
#  'Nigeria',
#  'Central African Republic',
#  'Liberia',
#  'Nigeria',
#  'Nigeria',
#  'Togo',
#  'Nigeria',
#  'Central African Republic',
#  'Gabon',
#  'Democratic Republic of the Congo',
#  'Liberia',
#  'Côte d’Ivoire',
#  'Democratic Republic of the Congo',
#  'Ghana',
#  'Cameroon',
#  'Nigeria',
#  'Guinea',
#  'Chad',
#  'Chad',
#  'Liberia',
#  'Nigeria',
#  'Cameroon',
#  'Cameroon',
#  'Tanzania',
#  'Nigeria',
#  'Burkina Faso',
#  'Nigeria',
#  'Togo',
#  'Central African Republic',
#  'Côte d’Ivoire',
#  'Côte d’Ivoire',
#  'Tanzania',
#  'Liberia',
#  'Democratic Republic of the Congo',
#  'Chad',
#  'Nigeria',
#  'Nigeria',
#  'Liberia',
#  'Liberia',
#  'Liberia',
#  'Senegal',
#  'Central African Republic',
#  'Côte d’Ivoire',
#  'Ghana',
#  'Benin',
#  'Burkina Faso',
#  'Kenya',
#  'Nigeria',
#  'Côte d’Ivoire',
#  'Nigeria',
#  'Nigeria',
#  'Uganda',
#  'Ghana',
#  'Côte d’Ivoire',
#  'Central African Republic',
#  'Nigeria',
#  'Central African Republic',
#  'Cameroon',
#  'Ghana',
#  'Tanzania',
#  'Tanzania',
#  'Democratic Republic of the Congo',
#  'Tanzania',
#  'Democratic Republic of the Congo',
#  'Sudan',
#  'Tanzania',
#  'Democratic Republic of the Congo',
#  'Senegal',
#  'Cameroon',
#  'Tanzania',
#  'Democratic Republic of the Congo',
#  'Nigeria',
#  'Angola',
#  'South Sudan',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Côte d’Ivoire',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Benin',
#  'Nigeria',
#  'Kenya',
#  'Nigeria',
#  'Benin',
#  'Nigeria',
#  'South Sudan',
#  'Nigeria',
#  'Nigeria',
#  'Togo',
#  'Congo',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Benin',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Tanzania',
#  'Zambia',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Tanzania',
#  'Nigeria',
#  'Cameroon',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Cameroon',
#  'Congo',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Guinea',
#  'Cameroon',
#  'Côte d’Ivoire',
#  'Nigeria',
#  'Nigeria',
#  'Democratic Republic of the Congo',
#  'Nigeria',
#  'Cameroon',
#  'Nigeria',
#  'Nigeria',
#  'Tanzania',
#  'Nigeria',
#  'Nigeria',
#  'Sudan',
#  'Tanzania',
#  'Ghana',
#  'Nigeria',
#  'Nigeria',
#  'Democratic Republic of the Congo',
#  'Côte d’Ivoire',
#  'Mali',
#  'Nigeria',
#  'Nigeria',
#  'Côte d’Ivoire',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Ghana',
#  'Nigeria',
#  'Nigeria',
#  'Kenya',
#  'Mali',
#  'Democratic Republic of the Congo',
#  'Central African Republic',
#  'Togo',
#  'Gabon',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Guinea-Bissau',
#  'Zimbabwe',
#  'Nigeria',
#  'Sudan',
#  'Tanzania',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Tanzania',
#  'Tanzania',
#  'Tanzania',
#  'Democratic Republic of the Congo',
#  'Togo',
#  'Nigeria',
#  'Nigeria',
#  'Zimbabwe',
#  'Nigeria',
#  'Nigeria',
#  'Cameroon',
#  'Gabon',
#  'Tanzania',
#  'Togo',
#  'Democratic Republic of the Congo',
#  'Cameroon',
#  'Nigeria',
#  'Togo',
#  'Nigeria',
#  'Cameroon',
#  'Cameroon',
#  'Côte d’Ivoire',
#  'Burkina Faso',
#  'Côte d’Ivoire',
#  'Nigeria',
#  'Nigeria',
#  'Angola',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Chad',
#  'Sudan',
#  'Cameroon',
#  'Kenya',
#  'Rwanda',
#  'Tanzania',
#  'Tanzania',
#  'Nigeria',
#  'Nigeria',
#  'Guinea',
#  'Tanzania',
#  'Cameroon',
#  'Nigeria',
#  'Democratic Republic of the Congo',
#  'Nigeria',
#  'Congo',
#  'Cameroon',
#  'Nigeria',
#  'Nigeria',
#  'Liberia',
#  'Ghana',
#  'Angola',
#  'Cameroon',
#  'Nigeria',
#  'Cameroon',
#  'Democratic Republic of the Congo',
#  'Nigeria',
#  'Guinea-Bissau',
#  'Democratic Republic of the Congo',
#  'Nigeria',
#  'Sierra Leone',
#  'Sierra Leone',
#  'Cameroon',
#  'Guinea',
#  'Democratic Republic of the Congo',
#  'Burkina Faso',
#  'Nigeria',
#  'Congo',
#  'Uganda',
#  'Gabon',
#  'Chad',
#  'Nigeria',
#  'Nigeria',
#  'Ghana',
#  'Nigeria',
#  'Democratic Republic of the Congo',
#  'Togo',
#  'Burkina Faso',
#  'Benin',
#  'Côte d’Ivoire',
#  'Zambia',
#  'Liberia',
#  'Guinea',
#  'Nigeria',
#  'Sierra Leone',
#  'Liberia',
#  'Nigeria',
#  'Liberia',
#  'Senegal',
#  'Nigeria',
#  'Tanzania',
#  'Cameroon',
#  'Nigeria',
#  'Liberia',
#  'Burkina Faso',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Côte d’Ivoire',
#  'Democratic Republic of the Congo',
#  'Angola',
#  'Nigeria',
#  'Nigeria',
#  'Tanzania',
#  'Ghana',
#  'Central African Republic',
#  'Cameroon',
#  'Nigeria',
#  'Congo',
#  'Côte d’Ivoire',
#  'Democratic Republic of the Congo',
#  'Cameroon',
#  'Democratic Republic of the Congo',
#  'Côte d’Ivoire',
#  'Congo',
#  'Tanzania',
#  'Ghana',
#  'Côte d’Ivoire',
#  'Central African Republic',
#  'Burkina Faso',
#  'Côte d’Ivoire',
#  'Malawi',
#  'Gabon',
#  'Cameroon',
#  'Democratic Republic of the Congo',
#  'Sudan',
#  'Tanzania',
#  'Malawi',
#  'Nigeria',
#  'Democratic Republic of the Congo',
#  'Zambia',
#  'Nigeria',
#  'Ghana',
#  'Togo',
#  'Cameroon',
#  'Angola',
#  'Côte d’Ivoire',
#  'Nigeria',
#  'Nigeria',
#  'Congo',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Guinea',
#  'Nigeria',
#  'Nigeria',
#  'Democratic Republic of the Congo',
#  'Zambia',
#  'Burkina Faso',
#  'Ghana',
#  'Zambia',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Cameroon',
#  'Cameroon',
#  'Democratic Republic of the Congo',
#  'Ghana',
#  'Democratic Republic of the Congo',
#  'Sierra Leone',
#  'Democratic Republic of the Congo',
#  'Ghana',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Ghana',
#  'Central African Republic',
#  'Democratic Republic of the Congo',
#  'Kenya',
#  'Uganda',
#  'Kenya',
#  'Kenya',
#  'Nigeria',
#  'Mozambique',
#  'Guinea',
#  'Congo',
#  'Guinea',
#  'Sudan',
#  'Cameroon',
#  'Cameroon',
#  'Central African Republic',
#  'Central African Republic',
#  'Cameroon',
#  'Nigeria',
#  'Democratic Republic of the Congo',
#  'Burkina Faso',
#  'Côte d’Ivoire',
#  'Sierra Leone',
#  'Democratic Republic of the Congo',
#  'Liberia',
#  'Malawi',
#  'Democratic Republic of the Congo',
#  'Nigeria',
#  'Democratic Republic of the Congo',
#  'Côte d’Ivoire',
#  'Zambia',
#  'Kenya',
#  'Kenya',
#  'Sudan',
#  'Democratic Republic of the Congo',
#  'Uganda',
#  'Kenya',
#  'Kenya',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Zambia',
#  'Uganda',
#  'Democratic Republic of the Congo',
#  'Angola',
#  'Zambia',
#  'Gabon',
#  'Democratic Republic of the Congo',
#  'Kenya',
#  'Zambia',
#  'Nigeria',
#  'Ghana',
#  'Congo',
#  'Cameroon',
#  'Nigeria',
#  'Guinea',
#  'Nigeria',
#  'Angola',
#  'Cameroon',
#  'Cameroon',
#  'Cameroon',
#  'Cameroon',
#  'Central African Republic',
#  'Nigeria',
#  'Cameroon',
#  'Democratic Republic of the Congo',
#  'Central African Republic',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Congo',
#  'Congo',
#  'Congo',
#  'Cameroon',
#  'Sierra Leone',
#  'Kenya',
#  'Liberia',
#  'Democratic Republic of the Congo',
#  'Cameroon',
#  'Cameroon',
#  'Guinea',
#  'Nigeria',
#  'Nigeria',
#  'Togo',
#  'Angola',
#  'Guinea-Bissau',
#  'Cameroon',
#  'Mozambique',
#  'Nigeria',
#  'Central African Republic',
#  'Cameroon',
#  'Tanzania',
#  'Zambia',
#  'Tanzania',
#  'Tanzania',
#  'Tanzania',
#  'Tanzania',
#  'Tanzania',
#  'Gabon',
#  'Cameroon',
#  'Mozambique',
#  'Zambia',
#  'Cameroon',
#  'Tanzania',
#  'Côte d’Ivoire',
#  'Cameroon',
#  'Benin',
#  'Nigeria',
#  'Guinea',
#  'Cameroon',
#  'Kenya',
#  'Senegal',
#  'Senegal',
#  'Nigeria',
#  'Cameroon',
#  'Democratic Republic of the Congo',
#  'Cameroon',
#  'Democratic Republic of the Congo',
#  'Senegal',
#  'Mozambique',
#  'Côte d’Ivoire',
#  'Nigeria',
#  'Congo',
#  'Sudan',
#  'Burkina Faso',
#  'Congo',
#  'Tanzania',
#  'Benin',
#  'Cameroon',
#  'Democratic Republic of the Congo',
#  'Guinea-Bissau',
#  'Côte d’Ivoire',
#  'Cameroon',
#  'Chad',
#  'Cameroon',
#  'South Sudan',
#  'Cameroon',
#  'Tanzania',
#  'Tanzania',
#  'Mali',
#  'Zambia',
#  'Kenya',
#  'Democratic Republic of the Congo',
#  'Zimbabwe',
#  'Angola',
#  'Benin',
#  'Zambia',
#  'Côte d’Ivoire',
#  'Democratic Republic of the Congo',
#  'Gabon',
#  'Cameroon',
#  'South Sudan',
#  'Mali',
#  'Uganda',
#  'Cameroon',
#  'Liberia',
#  'Nigeria',
#  'Nigeria',
#  'Central African Republic',
#  'Ghana',
#  'Guinea',
#  'Nigeria',
#  'Nigeria',
#  'Ghana',
#  'Angola',
#  'Nigeria',
#  'Democratic Republic of the Congo',
#  'South Africa',
#  'Central African Republic',
#  'Nigeria',
#  'Nigeria',
#  'Nigeria',
#  'Cameroon',
#  'Democratic Republic of the Congo',
#  'Cameroon',
#  'Cameroon',
#  'Ghana',
#  'Congo',
#  'Cameroon',
#  'Mozambique',
#  'Nigeria',
#  'Zimbabwe',
#  'Tanzania',
#  'Tanzania',
#  'Nigeria',
#  'Tanzania',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Congo',
#  'Angola',
#  'Nigeria',
#  'Democratic Republic of the Congo',
#  'Cameroon',
#  'Senegal',
#  'Democratic Republic of the Congo',
#  'South Sudan',
#  'Côte d’Ivoire',
#  'Côte d’Ivoire',
#  'Nigeria',
#  'Ghana',
#  ...]

# %%
hier_dict['Top-Level']['subgroups']['Indo-European']['subgroups']['Germanic']['subgroups']['West']['subgroups']['English']
# Out:
# {'subgroups': {'English': {'subgroups': {},
#    'name': 'English',
#    'country': ['United Kingdom'],
#    'latitude': [52.2486],
#    'longitude': [-0.2397],
#    'id': 3409,
#    'code': ['eng'],
#    'score': ['0']},
#   'Scots': {'subgroups': {},
#    'name': 'Scots',
#    'country': ['United Kingdom'],
#    'latitude': [56.5723],
#    'longitude': [-3.8661],
#    'id': 8032,
#    'code': ['sco'],
#    'score': ['5']}},
#  'name': 'English',
#  'country': ['United Kingdom', 'United Kingdom'],
#  'latitude': [52.2486, 56.5723],
#  'longitude': [-0.2397, -3.8661],
#  'id': 3408,
#  'code': ['eng', 'sco'],
#  'score': ['0', '5']}

# %%
tol_df_cc.iloc[0]
# Out:
# ISO_639                                                          aaa
# Language_Name                                                 Ghotuo
# Uninverted_Name                                               Ghotuo
# Country_Code                                                      NG
# Country_Name                                                 Nigeria
# Region_Code                                                      WAF
# Region_Name                                           Western Africa
# Area                                                          Africa
# L1_Users                                                      9000.0
# Digits                                                           4.0
# All_Users                                                     9000.0
# Countries                                                          1
# Family                                                   Niger-Congo
# Classification     Niger-Congo, Atlantic-Congo, Volta-Congo, Benu...
# Latitude                                                      7.1154
# Longitude                                                     5.9528
# EGIDS                                                             6a
# Is_Written                                                         F
# Institutional                                                      0
# Developing                                                         0
# Vigorous                                                           1
# In_Trouble                                                         0
# Dying                                                              0
# Extinct                                                            0
# Name: 0, dtype: object

# %%
hier_dict['Top-Level']['subgroups']['Niger-Congo']['subgroups']['Atlantic-Congo']['subgroups']['Volta-Congo']['id']
# Out:
# 2

# %% [markdown]
# #### **Structuring JSON**

# %%
def build_graph(hier_dict):
    hier_graph = {
        'nodes': [],
        'links': []
    }

    def build_graph_features(hier_dict):
        """
        build graph map
        """
        # basecase
        if not hier_dict['subgroups']:
            countries = hier_dict['country']
            scores = hier_dict['score']

            subgroup_node_data = {
                'id': hier_dict['id'],
                'name': hier_dict['name'],
                'country': max(set(countries), key=countries.count), # get most freq country from subgroups
                'score': max(set(scores), key=scores.count), # get most freq scores from subgroups
                'latitude': hier_dict['mean_latitude'],
                'longitude': hier_dict['mean_longitude'] 
            }
            hier_graph['nodes'].append(subgroup_node_data)
            subgroup_link_data = {
                'source' : hier_dict['id'],
                'target' : [float("-inf")]
            }
            hier_graph['links'].append(subgroup_link_data)
            return

        for subgroup in hier_dict['subgroups']:
            countries = hier_dict['subgroups'][subgroup]['country']
            scores = hier_dict['subgroups'][subgroup]['score']

            subgroup_node_data = {
                'id': hier_dict['id'],
                'name': hier_dict['name'],
                'country': max(set(countries), key=countries.count), # get most freq country from subgroups
                'score': max(set(scores), key=scores.count), # get most freq scores from subgroups
                'latitude': hier_dict['mean_latitude'],
                'longitude': hier_dict['mean_longitude'] 
            }
            hier_graph['nodes'].append(subgroup_node_data)
            subgroup_link_data = {
                'source' : hier_dict['id'],
                'target' : [hier_dict['subgroups'][sub]['id'] for sub in hier_dict['subgroups']]
            }
            hier_graph['links'].append(subgroup_link_data)
            return build_graph_features(hier_dict['subgroups'][subgroup])
            
    build_graph_features(hier_dict['Top-Level'])

    return hier_graph

fin_json = build_graph(hier_dict)
fin_json
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 56
#      52     build_graph_features(hier_dict['Top-Level'])
#      54     return hier_graph
# ---> 56 fin_json = build_graph(hier_dict)
#      57 fin_json
#
# Cell In[29], line 52, in build_graph(hier_dict)
#      49         hier_graph['links'].append(subgroup_link_data)
#      50         return build_graph_features(hier_dict['subgroups'][subgroup])
# ---> 52 build_graph_features(hier_dict['Top-Level'])
#      54 return hier_graph
#
# Cell In[29], line 41, in build_graph.<locals>.build_graph_features(hier_dict)
#      33 countries = hier_dict['subgroups'][subgroup]['country']
#      34 scores = hier_dict['subgroups'][subgroup]['score']
#      36 subgroup_node_data = {
#      37     'id': hier_dict['id'],
#      38     'name': hier_dict['name'],
#      39     'country': max(set(countries), key=countries.count), # get most freq country from subgroups
#      40     'score': max(set(scores), key=scores.count), # get most freq scores from subgroups
# ---> 41     'latitude': hier_dict['mean_latitude'],
#      42     'longitude': hier_dict['mean_longitude']
#      43 }
#      44 hier_graph['nodes'].append(subgroup_node_data)
#      45 subgroup_link_data = {
#      46     'source' : hier_dict['id'],
#      47     'target' : [hier_dict['subgroups'][sub]['id'] for sub in hier_dict['subgroups']]
#      48 }
#
# KeyError: 'mean_latitude'

# %%
fin_json['nodes'][522]['id']
# Out:
# 6033

# %%
fin_json['links'][522]
# Out:
# {'source': 6033, 'target': [-inf]}

# %%
max([s['id'] for s in fin_json['nodes']])
# Out:
# 10176

# %%
max([s['source'] for s in fin_json['links']])
# Out:
# 10176

# %%
max([max(s['target']) for s in fin_json['links']])
# Out:
# 10176

# %%
# make json unique to save space
nodes = sorted(fin_json['nodes'], key = lambda x : x['id'])
unique_nodes = []
for i in range(1, len(nodes)):
    if nodes[i] == nodes[i-1]:
        pass
    elif nodes[i]['id'] != -1:
        unique_nodes.append(nodes[i])
print(len(nodes))
print(len(unique_nodes))
# Out:
# 17140
# 14855

# %%
unique_nodes
# Out:
# [{'id': 0,
#   'name': 'Niger-Congo',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 3.7501451459606243,
#   'longitude': 12.096057298031228},
#  {'id': 0,
#   'name': 'Niger-Congo',
#   'country': 'Sudan',
#   'score': '6b',
#   'latitude': 3.7501451459606243,
#   'longitude': 12.096057298031228},
#  {'id': 0,
#   'name': 'Niger-Congo',
#   'country': 'Côte d’Ivoire',
#   'score': '6a',
#   'latitude': 3.7501451459606243,
#   'longitude': 12.096057298031228},
#  {'id': 0,
#   'name': 'Niger-Congo',
#   'country': 'Côte d’Ivoire',
#   'score': '6b',
#   'latitude': 3.7501451459606243,
#   'longitude': 12.096057298031228},
#  {'id': 1,
#   'name': 'Atlantic-Congo',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 3.309481752353367,
#   'longitude': 12.831211947863869},
#  {'id': 1,
#   'name': 'Atlantic-Congo',
#   'country': 'Senegal',
#   'score': '5',
#   'latitude': 3.309481752353367,
#   'longitude': 12.831211947863869},
#  {'id': 2,
#   'name': 'Volta-Congo',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 2.9053157131960337,
#   'longitude': 14.024252631578948},
#  {'id': 2,
#   'name': 'Volta-Congo',
#   'country': 'Ghana',
#   'score': '5',
#   'latitude': 2.9053157131960337,
#   'longitude': 14.024252631578948},
#  {'id': 2,
#   'name': 'Volta-Congo',
#   'country': 'Côte d’Ivoire',
#   'score': '6a',
#   'latitude': 2.9053157131960337,
#   'longitude': 14.024252631578948},
#  {'id': 2,
#   'name': 'Volta-Congo',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 2.9053157131960337,
#   'longitude': 14.024252631578948},
#  {'id': 2,
#   'name': 'Volta-Congo',
#   'country': 'Mali',
#   'score': '6a',
#   'latitude': 2.9053157131960337,
#   'longitude': 14.024252631578948},
#  {'id': 3,
#   'name': 'Benue-Congo',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 0.7373348435814456,
#   'longitude': 17.692743689320388},
#  {'id': 3,
#   'name': 'Benue-Congo',
#   'country': 'Cameroon',
#   'score': '6a',
#   'latitude': 0.7373348435814456,
#   'longitude': 17.692743689320388},
#  {'id': 3,
#   'name': 'Benue-Congo',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 0.7373348435814456,
#   'longitude': 17.692743689320388},
#  {'id': 3,
#   'name': 'Benue-Congo',
#   'country': 'Benin',
#   'score': '6a',
#   'latitude': 0.7373348435814456,
#   'longitude': 17.692743689320388},
#  {'id': 3,
#   'name': 'Benue-Congo',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 0.7373348435814456,
#   'longitude': 17.692743689320388},
#  {'id': 3,
#   'name': 'Benue-Congo',
#   'country': 'Nigeria',
#   'score': '5',
#   'latitude': 0.7373348435814456,
#   'longitude': 17.692743689320388},
#  {'id': 3,
#   'name': 'Benue-Congo',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 0.7373348435814456,
#   'longitude': 17.692743689320388},
#  {'id': 4,
#   'name': 'Edoid',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 6.602096296296296,
#   'longitude': 6.063244444444445},
#  {'id': 5,
#   'name': 'North-Central',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 6.999318181818182,
#   'longitude': 6.1255},
#  {'id': 5,
#   'name': 'North-Central',
#   'country': 'Nigeria',
#   'score': '4',
#   'latitude': 6.999318181818182,
#   'longitude': 6.1255},
#  {'id': 6,
#   'name': 'Ghotuo-Uneme-Yekhee',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 7.130175,
#   'longitude': 6.1696875},
#  {'id': 6,
#   'name': 'Ghotuo-Uneme-Yekhee',
#   'country': 'Nigeria',
#   'score': '5',
#   'latitude': 7.130175,
#   'longitude': 6.1696875},
#  {'id': 6,
#   'name': 'Ghotuo-Uneme-Yekhee',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 7.130175,
#   'longitude': 6.1696875},
#  {'id': 7,
#   'name': 'Ghotuo',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 7.1154,
#   'longitude': 5.9528},
#  {'id': 8,
#   'name': 'Plateau',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 9.431201999999999,
#   'longitude': 8.535722},
#  {'id': 8,
#   'name': 'Plateau',
#   'country': 'Nigeria',
#   'score': '8a',
#   'latitude': 9.431201999999999,
#   'longitude': 8.535722},
#  {'id': 8,
#   'name': 'Plateau',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 9.431201999999999,
#   'longitude': 8.535722},
#  {'id': 9,
#   'name': 'Alumic',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 9.0164,
#   'longitude': 8.612},
#  {'id': 10,
#   'name': 'Alumu-Tesu',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 9.0164,
#   'longitude': 8.612},
#  {'id': 11,
#   'name': 'Trans-New Guinea',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -6.2127614583333335,
#   'longitude': 143.06455354166664},
#  {'id': 11,
#   'name': 'Trans-New Guinea',
#   'country': 'Indonesia',
#   'score': '6a',
#   'latitude': -6.2127614583333335,
#   'longitude': 143.06455354166664},
#  {'id': 11,
#   'name': 'Trans-New Guinea',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -6.2127614583333335,
#   'longitude': 143.06455354166664},
#  {'id': 11,
#   'name': 'Trans-New Guinea',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -6.2127614583333335,
#   'longitude': 143.06455354166664},
#  {'id': 11,
#   'name': 'Trans-New Guinea',
#   'country': 'Indonesia',
#   'score': '6a',
#   'latitude': -6.2127614583333335,
#   'longitude': 143.06455354166664},
#  {'id': 11,
#   'name': 'Trans-New Guinea',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -6.2127614583333335,
#   'longitude': 143.06455354166664},
#  {'id': 11,
#   'name': 'Trans-New Guinea',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -6.2127614583333335,
#   'longitude': 143.06455354166664},
#  {'id': 11,
#   'name': 'Trans-New Guinea',
#   'country': 'Indonesia',
#   'score': '6a',
#   'latitude': -6.2127614583333335,
#   'longitude': 143.06455354166664},
#  {'id': 11,
#   'name': 'Trans-New Guinea',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -6.2127614583333335,
#   'longitude': 143.06455354166664},
#  {'id': 11,
#   'name': 'Trans-New Guinea',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -6.2127614583333335,
#   'longitude': 143.06455354166664},
#  {'id': 11,
#   'name': 'Trans-New Guinea',
#   'country': 'Indonesia',
#   'score': '6b',
#   'latitude': -6.2127614583333335,
#   'longitude': 143.06455354166664},
#  {'id': 11,
#   'name': 'Trans-New Guinea',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -6.2127614583333335,
#   'longitude': 143.06455354166664},
#  {'id': 11,
#   'name': 'Trans-New Guinea',
#   'country': 'Indonesia',
#   'score': '6b',
#   'latitude': -6.2127614583333335,
#   'longitude': 143.06455354166664},
#  {'id': 11,
#   'name': 'Trans-New Guinea',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -6.2127614583333335,
#   'longitude': 143.06455354166664},
#  {'id': 11,
#   'name': 'Trans-New Guinea',
#   'country': 'Indonesia',
#   'score': '6a',
#   'latitude': -6.2127614583333335,
#   'longitude': 143.06455354166664},
#  {'id': 11,
#   'name': 'Trans-New Guinea',
#   'country': 'Indonesia',
#   'score': '5',
#   'latitude': -6.2127614583333335,
#   'longitude': 143.06455354166664},
#  {'id': 11,
#   'name': 'Trans-New Guinea',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -6.2127614583333335,
#   'longitude': 143.06455354166664},
#  {'id': 11,
#   'name': 'Trans-New Guinea',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -6.2127614583333335,
#   'longitude': 143.06455354166664},
#  {'id': 11,
#   'name': 'Trans-New Guinea',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -6.2127614583333335,
#   'longitude': 143.06455354166664},
#  {'id': 11,
#   'name': 'Trans-New Guinea',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -6.2127614583333335,
#   'longitude': 143.06455354166664},
#  {'id': 11,
#   'name': 'Trans-New Guinea',
#   'country': 'Indonesia',
#   'score': '8a',
#   'latitude': -6.2127614583333335,
#   'longitude': 143.06455354166664},
#  {'id': 11,
#   'name': 'Trans-New Guinea',
#   'country': 'Indonesia',
#   'score': '6a',
#   'latitude': -6.2127614583333335,
#   'longitude': 143.06455354166664},
#  {'id': 11,
#   'name': 'Trans-New Guinea',
#   'country': 'Indonesia',
#   'score': '8b',
#   'latitude': -6.2127614583333335,
#   'longitude': 143.06455354166664},
#  {'id': 11,
#   'name': 'Trans-New Guinea',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -6.2127614583333335,
#   'longitude': 143.06455354166664},
#  {'id': 11,
#   'name': 'Trans-New Guinea',
#   'country': 'Indonesia',
#   'score': '6b',
#   'latitude': -6.2127614583333335,
#   'longitude': 143.06455354166664},
#  {'id': 11,
#   'name': 'Trans-New Guinea',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -6.2127614583333335,
#   'longitude': 143.06455354166664},
#  {'id': 12,
#   'name': 'Gogodala-Suki',
#   'country': 'Papua New Guinea',
#   'score': '6b',
#   'latitude': -8.084075,
#   'longitude': 142.391975},
#  {'id': 12,
#   'name': 'Gogodala-Suki',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -8.084075,
#   'longitude': 142.391975},
#  {'id': 13,
#   'name': 'Gogodala',
#   'country': 'Papua New Guinea',
#   'score': '6b',
#   'latitude': -8.089566666666668,
#   'longitude': 142.57626666666667},
#  {'id': 13,
#   'name': 'Gogodala',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -8.089566666666668,
#   'longitude': 142.57626666666667},
#  {'id': 13,
#   'name': 'Gogodala',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -8.089566666666668,
#   'longitude': 142.57626666666667},
#  {'id': 14,
#   'name': 'Ari',
#   'country': 'Papua New Guinea',
#   'score': '6b',
#   'latitude': -7.9172,
#   'longitude': 142.3877},
#  {'id': 15,
#   'name': 'Sepik',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -4.215368518518519,
#   'longitude': 142.57079814814816},
#  {'id': 15,
#   'name': 'Sepik',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -4.215368518518519,
#   'longitude': 142.57079814814816},
#  {'id': 15,
#   'name': 'Sepik',
#   'country': 'Papua New Guinea',
#   'score': '8b',
#   'latitude': -4.215368518518519,
#   'longitude': 142.57079814814816},
#  {'id': 15,
#   'name': 'Sepik',
#   'country': 'Papua New Guinea',
#   'score': '6b',
#   'latitude': -4.215368518518519,
#   'longitude': 142.57079814814816},
#  {'id': 15,
#   'name': 'Sepik',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -4.215368518518519,
#   'longitude': 142.57079814814816},
#  {'id': 15,
#   'name': 'Sepik',
#   'country': 'Papua New Guinea',
#   'score': '6b',
#   'latitude': -4.215368518518519,
#   'longitude': 142.57079814814816},
#  {'id': 15,
#   'name': 'Sepik',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -4.215368518518519,
#   'longitude': 142.57079814814816},
#  {'id': 16,
#   'name': 'Iwam',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -4.207433333333333,
#   'longitude': 141.98266666666666},
#  {'id': 16,
#   'name': 'Iwam',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -4.207433333333333,
#   'longitude': 141.98266666666666},
#  {'id': 17,
#   'name': 'Amal',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -4.0487,
#   'longitude': 141.9967},
#  {'id': 18,
#   'name': 'Indo-European',
#   'country': 'Albania',
#   'score': '1',
#   'latitude': 32.933431250000005,
#   'longitude': 52.38298175},
#  {'id': 18,
#   'name': 'Indo-European',
#   'country': 'India',
#   'score': '6a',
#   'latitude': 32.933431250000005,
#   'longitude': 52.38298175},
#  {'id': 18,
#   'name': 'Indo-European',
#   'country': 'Germany',
#   'score': '6a',
#   'latitude': 32.933431250000005,
#   'longitude': 52.38298175},
#  {'id': 18,
#   'name': 'Indo-European',
#   'country': 'Italy',
#   'score': '6b',
#   'latitude': 32.933431250000005,
#   'longitude': 52.38298175},
#  {'id': 18,
#   'name': 'Indo-European',
#   'country': 'Poland',
#   'score': '1',
#   'latitude': 32.933431250000005,
#   'longitude': 52.38298175},
#  {'id': 18,
#   'name': 'Indo-European',
#   'country': 'United Kingdom',
#   'score': '3',
#   'latitude': 32.933431250000005,
#   'longitude': 52.38298175},
#  {'id': 18,
#   'name': 'Indo-European',
#   'country': 'Greece',
#   'score': '8b',
#   'latitude': 32.933431250000005,
#   'longitude': 52.38298175},
#  {'id': 18,
#   'name': 'Indo-European',
#   'country': 'Armenia',
#   'score': '1',
#   'latitude': 32.933431250000005,
#   'longitude': 52.38298175},
#  {'id': 19,
#   'name': 'Albanian',
#   'country': 'Italy',
#   'score': '6b',
#   'latitude': 39.942299999999996,
#   'longitude': 20.164975},
#  {'id': 19,
#   'name': 'Albanian',
#   'country': 'Albania',
#   'score': '2',
#   'latitude': 39.942299999999996,
#   'longitude': 20.164975},
#  {'id': 20,
#   'name': 'Tosk',
#   'country': 'Italy',
#   'score': '6b',
#   'latitude': 39.24133333333333,
#   'longitude': 20.07483333333333},
#  {'id': 20,
#   'name': 'Tosk',
#   'country': 'Greece',
#   'score': '7',
#   'latitude': 39.24133333333333,
#   'longitude': 20.07483333333333},
#  {'id': 20,
#   'name': 'Tosk',
#   'country': 'Albania',
#   'score': '1',
#   'latitude': 39.24133333333333,
#   'longitude': 20.07483333333333},
#  {'id': 21,
#   'name': 'Albanian, Arbëreshë',
#   'country': 'Italy',
#   'score': '6b',
#   'latitude': 38.8985,
#   'longitude': 16.7019},
#  {'id': 22,
#   'name': 'Dravidian',
#   'country': 'India',
#   'score': '6a',
#   'latitude': 15.57873717948718,
#   'longitude': 78.42726794871795},
#  {'id': 22,
#   'name': 'Dravidian',
#   'country': 'India',
#   'score': '6b',
#   'latitude': 15.57873717948718,
#   'longitude': 78.42726794871795},
#  {'id': 22,
#   'name': 'Dravidian',
#   'country': 'India',
#   'score': '5',
#   'latitude': 15.57873717948718,
#   'longitude': 78.42726794871795},
#  {'id': 22,
#   'name': 'Dravidian',
#   'country': 'India',
#   'score': '6a',
#   'latitude': 15.57873717948718,
#   'longitude': 78.42726794871795},
#  {'id': 23,
#   'name': 'Southern',
#   'country': 'India',
#   'score': '6a',
#   'latitude': 11.764190476190478,
#   'longitude': 76.58060476190475},
#  {'id': 23,
#   'name': 'Southern',
#   'country': 'India',
#   'score': '6b',
#   'latitude': 11.764190476190478,
#   'longitude': 76.58060476190475},
#  {'id': 23,
#   'name': 'Southern',
#   'country': 'India',
#   'score': '6a',
#   'latitude': 11.764190476190478,
#   'longitude': 76.58060476190475},
#  {'id': 23,
#   'name': 'Southern',
#   'country': 'India',
#   'score': '6b',
#   'latitude': 11.764190476190478,
#   'longitude': 76.58060476190475},
#  {'id': 23,
#   'name': 'Southern',
#   'country': 'India',
#   'score': '6a',
#   'latitude': 11.764190476190478,
#   'longitude': 76.58060476190475},
#  {'id': 23,
#   'name': 'Southern',
#   'country': 'India',
#   'score': '6b',
#   'latitude': 11.764190476190478,
#   'longitude': 76.58060476190475},
#  {'id': 23,
#   'name': 'Southern',
#   'country': 'India',
#   'score': '6a',
#   'latitude': 11.764190476190478,
#   'longitude': 76.58060476190475},
#  {'id': 24,
#   'name': 'Tamil-Kannada',
#   'country': 'India',
#   'score': '6a',
#   'latitude': 11.827267857142857,
#   'longitude': 76.79775714285714},
#  {'id': 25,
#   'name': 'Tamil-Kodagu',
#   'country': 'India',
#   'score': '6a',
#   'latitude': 11.508395833333333,
#   'longitude': 76.87434583333334},
#  {'id': 26,
#   'name': 'Tamil-Malayalam',
#   'country': 'India',
#   'score': '6b',
#   'latitude': 11.521229411764708,
#   'longitude': 76.97508823529412},
#  {'id': 26,
#   'name': 'Tamil-Malayalam',
#   'country': 'India',
#   'score': '6a',
#   'latitude': 11.521229411764708,
#   'longitude': 76.97508823529412},
#  {'id': 26,
#   'name': 'Tamil-Malayalam',
#   'country': 'India',
#   'score': '6b',
#   'latitude': 11.521229411764708,
#   'longitude': 76.97508823529412},
#  {'id': 27,
#   'name': 'Malayalam',
#   'country': 'India',
#   'score': '6b',
#   'latitude': 10.688857142857144,
#   'longitude': 76.54301428571429},
#  {'id': 27,
#   'name': 'Malayalam',
#   'country': 'India',
#   'score': '2',
#   'latitude': 10.688857142857144,
#   'longitude': 76.54301428571429},
#  {'id': 27,
#   'name': 'Malayalam',
#   'country': 'India',
#   'score': '6a',
#   'latitude': 10.688857142857144,
#   'longitude': 76.54301428571429},
#  {'id': 27,
#   'name': 'Malayalam',
#   'country': 'India',
#   'score': '5',
#   'latitude': 10.688857142857144,
#   'longitude': 76.54301428571429},
#  {'id': 28,
#   'name': 'Aranadan',
#   'country': 'India',
#   'score': '6b',
#   'latitude': 11.3277,
#   'longitude': 76.131},
#  {'id': 29,
#   'name': 'Torricelli',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -3.5683385964912278,
#   'longitude': 142.6586649122807},
#  {'id': 29,
#   'name': 'Torricelli',
#   'country': 'Papua New Guinea',
#   'score': '6b',
#   'latitude': -3.5683385964912278,
#   'longitude': 142.6586649122807},
#  {'id': 29,
#   'name': 'Torricelli',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -3.5683385964912278,
#   'longitude': 142.6586649122807},
#  {'id': 29,
#   'name': 'Torricelli',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -3.5683385964912278,
#   'longitude': 142.6586649122807},
#  {'id': 30,
#   'name': 'Wapei-Palei',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -3.4974695652173913,
#   'longitude': 142.3658260869565},
#  {'id': 30,
#   'name': 'Wapei-Palei',
#   'country': 'Papua New Guinea',
#   'score': '6b',
#   'latitude': -3.4974695652173913,
#   'longitude': 142.3658260869565},
#  {'id': 31,
#   'name': 'Palei',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -3.51852,
#   'longitude': 142.49032},
#  {'id': 31,
#   'name': 'Palei',
#   'country': 'Papua New Guinea',
#   'score': '6b',
#   'latitude': -3.51852,
#   'longitude': 142.49032},
#  {'id': 31,
#   'name': 'Palei',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -3.51852,
#   'longitude': 142.49032},
#  {'id': 31,
#   'name': 'Palei',
#   'country': 'Papua New Guinea',
#   'score': '6b',
#   'latitude': -3.51852,
#   'longitude': 142.49032},
#  {'id': 31,
#   'name': 'Palei',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -3.51852,
#   'longitude': 142.49032},
#  {'id': 31,
#   'name': 'Palei',
#   'country': 'Papua New Guinea',
#   'score': '6b',
#   'latitude': -3.51852,
#   'longitude': 142.49032},
#  {'id': 31,
#   'name': 'Palei',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -3.51852,
#   'longitude': 142.49032},
#  {'id': 32,
#   'name': 'Ambrak',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -3.604,
#   'longitude': 142.5351},
#  {'id': 33,
#   'name': 'Kombio-Arapesh',
#   'country': 'Papua New Guinea',
#   'score': '6b',
#   'latitude': -3.51299,
#   'longitude': 142.83368},
#  {'id': 33,
#   'name': 'Kombio-Arapesh',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -3.51299,
#   'longitude': 142.83368},
#  {'id': 34,
#   'name': 'Arapesh',
#   'country': 'Papua New Guinea',
#   'score': '6b',
#   'latitude': -3.541975,
#   'longitude': 142.988475},
#  {'id': 34,
#   'name': 'Arapesh',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -3.541975,
#   'longitude': 142.988475},
#  {'id': 34,
#   'name': 'Arapesh',
#   'country': 'Papua New Guinea',
#   'score': '7',
#   'latitude': -3.541975,
#   'longitude': 142.988475},
#  {'id': 34,
#   'name': 'Arapesh',
#   'country': 'Papua New Guinea',
#   'score': '6b',
#   'latitude': -3.541975,
#   'longitude': 142.988475},
#  {'id': 35,
#   'name': 'Arapesh, Abu’',
#   'country': 'Papua New Guinea',
#   'score': '6b',
#   'latitude': -3.4341,
#   'longitude': 142.965},
#  {'id': 36,
#   'name': 'Austronesian',
#   'country': 'Indonesia',
#   'score': '6a',
#   'latitude': -2.6364719091673674,
#   'longitude': 129.38299722455847},
#  {'id': 36,
#   'name': 'Austronesian',
#   'country': 'China–Taiwan',
#   'score': '8b',
#   'latitude': -2.6364719091673674,
#   'longitude': 129.38299722455847},
#  {'id': 36,
#   'name': 'Austronesian',
#   'country': 'China–Taiwan',
#   'score': '5',
#   'latitude': -2.6364719091673674,
#   'longitude': 129.38299722455847},
#  {'id': 36,
#   'name': 'Austronesian',
#   'country': 'China–Taiwan',
#   'score': 'x10',
#   'latitude': -2.6364719091673674,
#   'longitude': 129.38299722455847},
#  {'id': 36,
#   'name': 'Austronesian',
#   'country': 'China–Taiwan',
#   'score': '5',
#   'latitude': -2.6364719091673674,
#   'longitude': 129.38299722455847},
#  {'id': 36,
#   'name': 'Austronesian',
#   'country': 'China–Taiwan',
#   'score': '7',
#   'latitude': -2.6364719091673674,
#   'longitude': 129.38299722455847},
#  {'id': 36,
#   'name': 'Austronesian',
#   'country': 'China–Taiwan',
#   'score': '8b',
#   'latitude': -2.6364719091673674,
#   'longitude': 129.38299722455847},
#  {'id': 36,
#   'name': 'Austronesian',
#   'country': 'China–Taiwan',
#   'score': '4',
#   'latitude': -2.6364719091673674,
#   'longitude': 129.38299722455847},
#  {'id': 36,
#   'name': 'Austronesian',
#   'country': 'China–Taiwan',
#   'score': '8b',
#   'latitude': -2.6364719091673674,
#   'longitude': 129.38299722455847},
#  {'id': 37,
#   'name': 'Malayo-Polynesian',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -3.042325021349274,
#   'longitude': 129.51037959009395},
#  {'id': 37,
#   'name': 'Malayo-Polynesian',
#   'country': 'Philippines',
#   'score': '5',
#   'latitude': -3.042325021349274,
#   'longitude': 129.51037959009395},
#  {'id': 37,
#   'name': 'Malayo-Polynesian',
#   'country': 'Indonesia',
#   'score': '6b',
#   'latitude': -3.042325021349274,
#   'longitude': 129.51037959009395},
#  {'id': 37,
#   'name': 'Malayo-Polynesian',
#   'country': 'Indonesia',
#   'score': '6a',
#   'latitude': -3.042325021349274,
#   'longitude': 129.51037959009395},
#  {'id': 37,
#   'name': 'Malayo-Polynesian',
#   'country': 'Indonesia',
#   'score': '5',
#   'latitude': -3.042325021349274,
#   'longitude': 129.51037959009395},
#  {'id': 37,
#   'name': 'Malayo-Polynesian',
#   'country': 'Indonesia',
#   'score': '6a',
#   'latitude': -3.042325021349274,
#   'longitude': 129.51037959009395},
#  {'id': 37,
#   'name': 'Malayo-Polynesian',
#   'country': 'Indonesia',
#   'score': '5',
#   'latitude': -3.042325021349274,
#   'longitude': 129.51037959009395},
#  {'id': 37,
#   'name': 'Malayo-Polynesian',
#   'country': 'Malaysia',
#   'score': '6b',
#   'latitude': -3.042325021349274,
#   'longitude': 129.51037959009395},
#  {'id': 37,
#   'name': 'Malayo-Polynesian',
#   'country': 'Indonesia',
#   'score': '6a',
#   'latitude': -3.042325021349274,
#   'longitude': 129.51037959009395},
#  {'id': 37,
#   'name': 'Malayo-Polynesian',
#   'country': 'Indonesia',
#   'score': '6b',
#   'latitude': -3.042325021349274,
#   'longitude': 129.51037959009395},
#  {'id': 37,
#   'name': 'Malayo-Polynesian',
#   'country': 'Guam',
#   'score': '1',
#   'latitude': -3.042325021349274,
#   'longitude': 129.51037959009395},
#  {'id': 37,
#   'name': 'Malayo-Polynesian',
#   'country': 'Philippines',
#   'score': 'x10',
#   'latitude': -3.042325021349274,
#   'longitude': 129.51037959009395},
#  {'id': 37,
#   'name': 'Malayo-Polynesian',
#   'country': 'Indonesia',
#   'score': '6a',
#   'latitude': -3.042325021349274,
#   'longitude': 129.51037959009395},
#  {'id': 37,
#   'name': 'Malayo-Polynesian',
#   'country': 'Myanmar',
#   'score': '6b',
#   'latitude': -3.042325021349274,
#   'longitude': 129.51037959009395},
#  {'id': 37,
#   'name': 'Malayo-Polynesian',
#   'country': 'Indonesia',
#   'score': '6a',
#   'latitude': -3.042325021349274,
#   'longitude': 129.51037959009395},
#  {'id': 37,
#   'name': 'Malayo-Polynesian',
#   'country': 'Palau',
#   'score': '2',
#   'latitude': -3.042325021349274,
#   'longitude': 129.51037959009395},
#  {'id': 37,
#   'name': 'Malayo-Polynesian',
#   'country': 'Indonesia',
#   'score': '6a',
#   'latitude': -3.042325021349274,
#   'longitude': 129.51037959009395},
#  {'id': 38,
#   'name': 'Central-Eastern Malayo-Polynesian',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -8.265089458272328,
#   'longitude': 139.34808184480235},
#  {'id': 38,
#   'name': 'Central-Eastern Malayo-Polynesian',
#   'country': 'Indonesia',
#   'score': '6a',
#   'latitude': -8.265089458272328,
#   'longitude': 139.34808184480235},
#  {'id': 38,
#   'name': 'Central-Eastern Malayo-Polynesian',
#   'country': 'Indonesia',
#   'score': '6b',
#   'latitude': -8.265089458272328,
#   'longitude': 139.34808184480235},
#  {'id': 38,
#   'name': 'Central-Eastern Malayo-Polynesian',
#   'country': 'Indonesia',
#   'score': '6a',
#   'latitude': -8.265089458272328,
#   'longitude': 139.34808184480235},
#  {'id': 38,
#   'name': 'Central-Eastern Malayo-Polynesian',
#   'country': 'Indonesia',
#   'score': '6b',
#   'latitude': -8.265089458272328,
#   'longitude': 139.34808184480235},
#  {'id': 38,
#   'name': 'Central-Eastern Malayo-Polynesian',
#   'country': 'Indonesia',
#   'score': '6a',
#   'latitude': -8.265089458272328,
#   'longitude': 139.34808184480235},
#  {'id': 38,
#   'name': 'Central-Eastern Malayo-Polynesian',
#   'country': 'Indonesia',
#   'score': '6b',
#   'latitude': -8.265089458272328,
#   'longitude': 139.34808184480235},
#  {'id': 38,
#   'name': 'Central-Eastern Malayo-Polynesian',
#   'country': 'Indonesia',
#   'score': 'x10',
#   'latitude': -8.265089458272328,
#   'longitude': 139.34808184480235},
#  {'id': 38,
#   'name': 'Central-Eastern Malayo-Polynesian',
#   'country': 'Indonesia',
#   'score': '6a',
#   'latitude': -8.265089458272328,
#   'longitude': 139.34808184480235},
#  {'id': 38,
#   'name': 'Central-Eastern Malayo-Polynesian',
#   'country': 'Indonesia',
#   'score': '6b',
#   'latitude': -8.265089458272328,
#   'longitude': 139.34808184480235},
#  {'id': 38,
#   'name': 'Central-Eastern Malayo-Polynesian',
#   'country': 'Indonesia',
#   'score': '7',
#   'latitude': -8.265089458272328,
#   'longitude': 139.34808184480235},
#  {'id': 39,
#   'name': 'Eastern Malayo-Polynesian',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -8.778947731397459,
#   'longitude': 141.99775807622504},
#  {'id': 39,
#   'name': 'Eastern Malayo-Polynesian',
#   'country': 'Indonesia',
#   'score': '6b',
#   'latitude': -8.778947731397459,
#   'longitude': 141.99775807622504},
#  {'id': 40,
#   'name': 'Oceanic',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -9.335966796874999,
#   'longitude': 142.6824912109375},
#  {'id': 40,
#   'name': 'Oceanic',
#   'country': 'Vanuatu',
#   'score': '6b',
#   'latitude': -9.335966796874999,
#   'longitude': 142.6824912109375},
#  {'id': 40,
#   'name': 'Oceanic',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -9.335966796874999,
#   'longitude': 142.6824912109375},
#  {'id': 40,
#   'name': 'Oceanic',
#   'country': 'Solomon Islands',
#   'score': '8b',
#   'latitude': -9.335966796874999,
#   'longitude': 142.6824912109375},
#  {'id': 40,
#   'name': 'Oceanic',
#   'country': 'Papua New Guinea',
#   'score': '8b',
#   'latitude': -9.335966796874999,
#   'longitude': 142.6824912109375},
#  {'id': 40,
#   'name': 'Oceanic',
#   'country': 'Micronesia',
#   'score': '2',
#   'latitude': -9.335966796874999,
#   'longitude': 142.6824912109375},
#  {'id': 41,
#   'name': 'Western Oceanic',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -6.565358333333334,
#   'longitude': 149.56261958333332},
#  {'id': 41,
#   'name': 'Western Oceanic',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -6.565358333333334,
#   'longitude': 149.56261958333332},
#  {'id': 42,
#   'name': 'Papuan Tip',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -9.8320328125,
#   'longitude': 150.0161109375},
#  {'id': 43,
#   'name': 'Nuclear',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -9.916795454545452,
#   'longitude': 150.35724318181818},
#  {'id': 44,
#   'name': 'North Papuan Mainland-D’Entrecasteaux',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -9.786067647058823,
#   'longitude': 150.35090588235298},
#  {'id': 44,
#   'name': 'North Papuan Mainland-D’Entrecasteaux',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -9.786067647058823,
#   'longitude': 150.35090588235298},
#  {'id': 44,
#   'name': 'North Papuan Mainland-D’Entrecasteaux',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -9.786067647058823,
#   'longitude': 150.35090588235298},
#  {'id': 45,
#   'name': 'Are-Taupota',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -9.910418750000002,
#   'longitude': 150.0887625},
#  {'id': 46,
#   'name': 'Are',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -9.586242857142855,
#   'longitude': 149.77525714285713},
#  {'id': 46,
#   'name': 'Are',
#   'country': 'Papua New Guinea',
#   'score': '6b',
#   'latitude': -9.586242857142855,
#   'longitude': 149.77525714285713},
#  {'id': 46,
#   'name': 'Are',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -9.586242857142855,
#   'longitude': 149.77525714285713},
#  {'id': 46,
#   'name': 'Are',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -9.586242857142855,
#   'longitude': 149.77525714285713},
#  {'id': 47,
#   'name': 'Miniafia Oyan',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -9.1768,
#   'longitude': 149.2326},
#  {'id': 48,
#   'name': 'Angan',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -7.1991000000000005,
#   'longitude': 145.9837230769231},
#  {'id': 49,
#   'name': 'Nuclear Angan',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -7.198508333333334,
#   'longitude': 145.96275833333337},
#  {'id': 49,
#   'name': 'Nuclear Angan',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -7.198508333333334,
#   'longitude': 145.96275833333337},
#  {'id': 49,
#   'name': 'Nuclear Angan',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -7.198508333333334,
#   'longitude': 145.96275833333337},
#  {'id': 49,
#   'name': 'Nuclear Angan',
#   'country': 'Papua New Guinea',
#   'score': '8b',
#   'latitude': -7.198508333333334,
#   'longitude': 145.96275833333337},
#  {'id': 49,
#   'name': 'Nuclear Angan',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -7.198508333333334,
#   'longitude': 145.96275833333337},
#  {'id': 49,
#   'name': 'Nuclear Angan',
#   'country': 'Papua New Guinea',
#   'score': '8b',
#   'latitude': -7.198508333333334,
#   'longitude': 145.96275833333337},
#  {'id': 49,
#   'name': 'Nuclear Angan',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -7.198508333333334,
#   'longitude': 145.96275833333337},
#  {'id': 50,
#   'name': 'Ankave',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -7.2047,
#   'longitude': 145.7713},
#  {'id': 51,
#   'name': 'Afro-Asiatic',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 13.600282352941173,
#   'longitude': 22.832421288515405},
#  {'id': 51,
#   'name': 'Afro-Asiatic',
#   'country': 'Israel',
#   'score': '6a',
#   'latitude': 13.600282352941173,
#   'longitude': 22.832421288515405},
#  {'id': 51,
#   'name': 'Afro-Asiatic',
#   'country': 'Ethiopia',
#   'score': '6a',
#   'latitude': 13.600282352941173,
#   'longitude': 22.832421288515405},
#  {'id': 51,
#   'name': 'Afro-Asiatic',
#   'country': 'Ethiopia',
#   'score': '4',
#   'latitude': 13.600282352941173,
#   'longitude': 22.832421288515405},
#  {'id': 51,
#   'name': 'Afro-Asiatic',
#   'country': 'Algeria',
#   'score': '6b',
#   'latitude': 13.600282352941173,
#   'longitude': 22.832421288515405},
#  {'id': 51,
#   'name': 'Afro-Asiatic',
#   'country': 'Ethiopia',
#   'score': '8b',
#   'latitude': 13.600282352941173,
#   'longitude': 22.832421288515405},
#  {'id': 52,
#   'name': 'Chadic',
#   'country': 'Cameroon',
#   'score': '6a',
#   'latitude': 10.519496216216217,
#   'longitude': 13.222930810810809},
#  {'id': 52,
#   'name': 'Chadic',
#   'country': 'Nigeria',
#   'score': '6a',
#   'latitude': 10.519496216216217,
#   'longitude': 13.222930810810809},
#  {'id': 52,
#   'name': 'Chadic',
#   'country': 'Chad',
#   'score': '6a',
#   'latitude': 10.519496216216217,
#   'longitude': 13.222930810810809},
#  {'id': 52,
#   'name': 'Chadic',
#   'country': 'Chad',
#   'score': '5',
#   'latitude': 10.519496216216217,
#   'longitude': 13.222930810810809},
#  {'id': 53,
#   'name': 'Biu-Mandara',
#   'country': 'Cameroon',
#   'score': '6a',
#   'latitude': 10.751855844155843,
#   'longitude': 13.775871428571424},
#  {'id': 53,
#   'name': 'Biu-Mandara',
#   'country': 'Cameroon',
#   'score': '5',
#   'latitude': 10.751855844155843,
#   'longitude': 13.775871428571424},
#  {'id': 54,
#   'name': 'B',
#   'country': 'Cameroon',
#   'score': '6a',
#   'latitude': 11.751515384615384,
#   'longitude': 14.926799999999998},
#  {'id': 54,
#   'name': 'B',
#   'country': 'Chad',
#   'score': 'x10',
#   'latitude': 11.751515384615384,
#   'longitude': 14.926799999999998},
#  {'id': 55,
#   'name': 'B.1',
#   'country': 'Cameroon',
#   'score': '6a',
#   'latitude': 12.07281,
#   'longitude': 14.801400000000001},
#  {'id': 55,
#   'name': 'B.1',
#   'country': 'Chad',
#   'score': '6a',
#   'latitude': 12.07281,
#   'longitude': 14.801400000000001},
#  {'id': 55,
#   'name': 'B.1',
#   'country': 'Cameroon',
#   'score': '6b',
#   'latitude': 12.07281,
#   'longitude': 14.801400000000001},
#  {'id': 55,
#   'name': 'B.1',
#   'country': 'Nigeria',
#   'score': '8b',
#   'latitude': 12.07281,
#   'longitude': 14.801400000000001},
#  {'id': 56,
#   'name': 'Kotoko Proper',
#   'country': 'Cameroon',
#   'score': '6a',
#   'latitude': 12.187583333333334,
#   'longitude': 14.835299999999998},
#  {'id': 56,
#   'name': 'Kotoko Proper',
#   'country': 'Cameroon',
#   'score': '6b',
#   'latitude': 12.187583333333334,
#   'longitude': 14.835299999999998},
#  {'id': 57,
#   'name': 'North',
#   'country': 'Cameroon',
#   'score': '6a',
#   'latitude': 12.365550000000002,
#   'longitude': 14.770499999999998},
#  {'id': 57,
#   'name': 'North',
#   'country': 'Cameroon',
#   'score': '7',
#   'latitude': 12.365550000000002,
#   'longitude': 14.770499999999998},
#  {'id': 57,
#   'name': 'North',
#   'country': 'Cameroon',
#   'score': '6b',
#   'latitude': 12.365550000000002,
#   'longitude': 14.770499999999998},
#  {'id': 58,
#   'name': 'Afade',
#   'country': 'Cameroon',
#   'score': '6a',
#   'latitude': 12.2094,
#   'longitude': 14.6759},
#  {'id': 59,
#   'name': 'Tupian',
#   'country': 'Brazil',
#   'score': '6b',
#   'latitude': -10.052630434782609,
#   'longitude': -57.83679710144928},
#  {'id': 59,
#   'name': 'Tupian',
#   'country': 'Brazil',
#   'score': 'x10',
#   'latitude': -10.052630434782609,
#   'longitude': -57.83679710144928},
#  {'id': 59,
#   'name': 'Tupian',
#   'country': 'Brazil',
#   'score': '8a',
#   'latitude': -10.052630434782609,
#   'longitude': -57.83679710144928},
#  {'id': 59,
#   'name': 'Tupian',
#   'country': 'Brazil',
#   'score': 'x10',
#   'latitude': -10.052630434782609,
#   'longitude': -57.83679710144928},
#  {'id': 59,
#   'name': 'Tupian',
#   'country': 'Brazil',
#   'score': '8b',
#   'latitude': -10.052630434782609,
#   'longitude': -57.83679710144928},
#  {'id': 59,
#   'name': 'Tupian',
#   'country': 'Brazil',
#   'score': '6b',
#   'latitude': -10.052630434782609,
#   'longitude': -57.83679710144928},
#  {'id': 59,
#   'name': 'Tupian',
#   'country': 'Brazil',
#   'score': 'x10',
#   'latitude': -10.052630434782609,
#   'longitude': -57.83679710144928},
#  {'id': 59,
#   'name': 'Tupian',
#   'country': 'Brazil',
#   'score': '6a',
#   'latitude': -10.052630434782609,
#   'longitude': -57.83679710144928},
#  {'id': 59,
#   'name': 'Tupian',
#   'country': 'Brazil',
#   'score': '8b',
#   'latitude': -10.052630434782609,
#   'longitude': -57.83679710144928},
#  {'id': 59,
#   'name': 'Tupian',
#   'country': 'Brazil',
#   'score': '5',
#   'latitude': -10.052630434782609,
#   'longitude': -57.83679710144928},
#  {'id': 59,
#   'name': 'Tupian',
#   'country': 'Brazil',
#   'score': '6b',
#   'latitude': -10.052630434782609,
#   'longitude': -57.83679710144928},
#  {'id': 59,
#   'name': 'Tupian',
#   'country': 'Brazil',
#   'score': '8b',
#   'latitude': -10.052630434782609,
#   'longitude': -57.83679710144928},
#  {'id': 60,
#   'name': 'Tupí-Guaraní',
#   'country': 'Brazil',
#   'score': 'x10',
#   'latitude': -10.113199999999999,
#   'longitude': -56.82614090909092},
#  {'id': 60,
#   'name': 'Tupí-Guaraní',
#   'country': 'Brazil',
#   'score': '6b',
#   'latitude': -10.113199999999999,
#   'longitude': -56.82614090909092},
#  {'id': 60,
#   'name': 'Tupí-Guaraní',
#   'country': 'Brazil',
#   'score': '6a',
#   'latitude': -10.113199999999999,
#   'longitude': -56.82614090909092},
#  {'id': 60,
#   'name': 'Tupí-Guaraní',
#   'country': 'Brazil',
#   'score': '6b',
#   'latitude': -10.113199999999999,
#   'longitude': -56.82614090909092},
#  {'id': 60,
#   'name': 'Tupí-Guaraní',
#   'country': 'Peru',
#   'score': '8b',
#   'latitude': -10.113199999999999,
#   'longitude': -56.82614090909092},
#  {'id': 60,
#   'name': 'Tupí-Guaraní',
#   'country': 'Paraguay',
#   'score': '5',
#   'latitude': -10.113199999999999,
#   'longitude': -56.82614090909092},
#  {'id': 60,
#   'name': 'Tupí-Guaraní',
#   'country': 'Bolivia',
#   'score': 'x10',
#   'latitude': -10.113199999999999,
#   'longitude': -56.82614090909092},
#  {'id': 61,
#   'name': 'Wayampí',
#   'country': 'Brazil',
#   'score': 'x10',
#   'latitude': -1.3255714285714286,
#   'longitude': -48.802314285714296},
#  {'id': 61,
#   'name': 'Wayampí',
#   'country': 'French Guiana',
#   'score': '6b',
#   'latitude': -1.3255714285714286,
#   'longitude': -48.802314285714296},
#  {'id': 62,
#   'name': 'Amanayé',
#   'country': 'Brazil',
#   'score': '8b',
#   'latitude': -2.691525,
#   'longitude': -47.6604},
#  {'id': 62,
#   'name': 'Amanayé',
#   'country': 'Brazil',
#   'score': '6a',
#   'latitude': -2.691525,
#   'longitude': -47.6604},
#  {'id': 62,
#   'name': 'Amanayé',
#   'country': 'Brazil',
#   'score': '5',
#   'latitude': -2.691525,
#   'longitude': -47.6604},
#  {'id': 62,
#   'name': 'Amanayé',
#   'country': 'Brazil',
#   'score': 'x10',
#   'latitude': -2.691525,
#   'longitude': -47.6604},
#  {'id': 63,
#   'name': 'Anambé',
#   'country': 'Brazil',
#   'score': '8b',
#   'latitude': -2.7139,
#   'longitude': -49.2988},
#  {'id': 64,
#   'name': 'Semitic',
#   'country': 'Israel',
#   'score': '6a',
#   'latitude': 24.873815714285715,
#   'longitude': 38.04456571428572},
#  {'id': 64,
#   'name': 'Semitic',
#   'country': 'Ethiopia',
#   'score': '6a',
#   'latitude': 24.873815714285715,
#   'longitude': 38.04456571428572},
#  {'id': 65,
#   'name': 'Central',
#   'country': 'Israel',
#   'score': '3',
#   'latitude': 29.50742745098039,
#   'longitude': 35.927988235294116},
#  {'id': 65,
#   'name': 'Central',
#   'country': 'Israel',
#   'score': '7',
#   'latitude': 29.50742745098039,
#   'longitude': 35.927988235294116},
#  {'id': 65,
#   'name': 'Central',
#   'country': 'Yemen',
#   'score': '6a',
#   'latitude': 29.50742745098039,
#   'longitude': 35.927988235294116},
#  {'id': 66,
#   'name': 'South',
#   'country': 'Israel',
#   'score': '3',
#   'latitude': 27.513060000000003,
#   'longitude': 33.51832285714285},
#  {'id': 66,
#   'name': 'South',
#   'country': 'Israel',
#   'score': '1',
#   'latitude': 27.513060000000003,
#   'longitude': 33.51832285714285},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Algeria',
#   'score': '6a',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Tajikistan',
#   'score': '6a',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Bahrain',
#   'score': '3',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Iraq',
#   'score': '3',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Yemen',
#   'score': '5',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Saudi Arabia',
#   'score': '6a',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Oman',
#   'score': '6a',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Cyprus',
#   'score': '8a',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Oman',
#   'score': '6a',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Tunisia',
#   'score': '3',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Egypt',
#   'score': '6a',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Kuwait',
#   'score': '3',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Jordan',
#   'score': '3',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Israel',
#   'score': '5',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Israel',
#   'score': '7',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Syria',
#   'score': '3',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Sudan',
#   'score': '3',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Algeria',
#   'score': '3',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Saudi Arabia',
#   'score': '3',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Morocco',
#   'score': '3',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Egypt',
#   'score': '3',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Uzbekistan',
#   'score': '8a',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Egypt',
#   'score': '6a',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Yemen',
#   'score': '6a',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Libya',
#   'score': '3',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Yemen',
#   'score': '6a',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Iraq',
#   'score': '6a',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Israel',
#   'score': '6a',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Mauritania',
#   'score': '3',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Malta',
#   'score': '1',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Chad',
#   'score': '3',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'United Arab Emirates',
#   'score': '6a',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Israel',
#   'score': '6a',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 67,
#   'name': 'Arabic',
#   'country': 'Israel',
#   'score': '7',
#   'latitude': 27.40739411764706,
#   'longitude': 33.47421764705882},
#  {'id': 68,
#   'name': 'Arabic, Algerian Saharan Spoken',
#   'country': 'Algeria',
#   'score': '6a',
#   'latitude': 28.2657,
#   'longitude': 5.3649},
#  {'id': 69,
#   'name': 'Cariban',
#   'country': 'Brazil',
#   'score': '6a',
#   'latitude': 2.6739068965517236,
#   'longitude': -61.09641034482759},
#  {'id': 69,
#   'name': 'Cariban',
#   'country': 'Brazil',
#   'score': '6b',
#   'latitude': 2.6739068965517236,
#   'longitude': -61.09641034482759},
#  {'id': 69,
#   'name': 'Cariban',
#   'country': 'Suriname',
#   'score': '8b',
#   'latitude': 2.6739068965517236,
#   'longitude': -61.09641034482759},
#  {'id': 69,
#   'name': 'Cariban',
#   'country': 'Venezuela',
#   'score': '8b',
#   'latitude': 2.6739068965517236,
#   'longitude': -61.09641034482759},
#  {'id': 69,
#   'name': 'Cariban',
#   'country': 'Venezuela',
#   'score': '6b',
#   'latitude': 2.6739068965517236,
#   'longitude': -61.09641034482759},
#  {'id': 69,
#   'name': 'Cariban',
#   'country': 'Brazil',
#   'score': '4',
#   'latitude': 2.6739068965517236,
#   'longitude': -61.09641034482759},
#  {'id': 69,
#   'name': 'Cariban',
#   'country': 'Venezuela',
#   'score': '6b',
#   'latitude': 2.6739068965517236,
#   'longitude': -61.09641034482759},
#  {'id': 69,
#   'name': 'Cariban',
#   'country': 'Brazil',
#   'score': '8a',
#   'latitude': 2.6739068965517236,
#   'longitude': -61.09641034482759},
#  {'id': 70,
#   'name': 'South Amazonian',
#   'country': 'Brazil',
#   'score': '6a',
#   'latitude': -6.955179999999999,
#   'longitude': -56.07586},
#  {'id': 70,
#   'name': 'South Amazonian',
#   'country': 'Brazil',
#   'score': '6b',
#   'latitude': -6.955179999999999,
#   'longitude': -56.07586},
#  {'id': 70,
#   'name': 'South Amazonian',
#   'country': 'Venezuela',
#   'score': '5',
#   'latitude': -6.955179999999999,
#   'longitude': -56.07586},
#  {'id': 71,
#   'name': 'Arara',
#   'country': 'Brazil',
#   'score': '6a',
#   'latitude': -7.55065,
#   'longitude': -53.31075},
#  {'id': 72,
#   'name': 'Arára, Pará',
#   'country': 'Brazil',
#   'score': '6a',
#   'latitude': -3.7418,
#   'longitude': -53.1307},
#  {'id': 73,
#   'name': 'Cushitic',
#   'country': 'Ethiopia',
#   'score': '6a',
#   'latitude': 4.525551111111111,
#   'longitude': 38.788264444444444},
#  {'id': 73,
#   'name': 'Cushitic',
#   'country': 'Tanzania',
#   'score': '6a',
#   'latitude': 4.525551111111111,
#   'longitude': 38.788264444444444},
#  {'id': 73,
#   'name': 'Cushitic',
#   'country': 'Ethiopia',
#   'score': '4',
#   'latitude': 4.525551111111111,
#   'longitude': 38.788264444444444},
#  {'id': 73,
#   'name': 'Cushitic',
#   'country': 'Sudan',
#   'score': '5',
#   'latitude': 4.525551111111111,
#   'longitude': 38.788264444444444},
#  {'id': 74,
#   'name': 'East',
#   'country': 'Eritrea',
#   'score': '4',
#   'latitude': 4.915887878787879,
#   'longitude': 39.47778484848485},
#  {'id': 74,
#   'name': 'East',
#   'country': 'Ethiopia',
#   'score': '4',
#   'latitude': 4.915887878787879,
#   'longitude': 39.47778484848485},
#  {'id': 74,
#   'name': 'East',
#   'country': 'Ethiopia',
#   'score': '6a',
#   'latitude': 4.915887878787879,
#   'longitude': 39.47778484848485},
#  {'id': 74,
#   'name': 'East',
#   'country': 'Somalia',
#   'score': '8b',
#   'latitude': 4.915887878787879,
#   'longitude': 39.47778484848485},
#  {'id': 74,
#   'name': 'East',
#   'country': 'Kenya',
#   'score': '6a',
#   'latitude': 4.915887878787879,
#   'longitude': 39.47778484848485},
#  {'id': 74,
#   'name': 'East',
#   'country': 'Somalia',
#   'score': '6a',
#   'latitude': 4.915887878787879,
#   'longitude': 39.47778484848485},
#  {'id': 74,
#   'name': 'East',
#   'country': 'Ethiopia',
#   'score': '6a',
#   'latitude': 4.915887878787879,
#   'longitude': 39.47778484848485},
#  {'id': 74,
#   'name': 'East',
#   'country': 'Ethiopia',
#   'score': '5',
#   'latitude': 4.915887878787879,
#   'longitude': 39.47778484848485},
#  {'id': 74,
#   'name': 'East',
#   'country': 'Kenya',
#   'score': '8a',
#   'latitude': 4.915887878787879,
#   'longitude': 39.47778484848485},
#  {'id': 75,
#   'name': 'Saho-Afar',
#   'country': 'Ethiopia',
#   'score': '2',
#   'latitude': 13.2253,
#   'longitude': 40.6524},
#  {'id': 75,
#   'name': 'Saho-Afar',
#   'country': 'Eritrea',
#   'score': '4',
#   'latitude': 13.2253,
#   'longitude': 40.6524},
#  {'id': 76,
#   'name': 'Afar',
#   'country': 'Ethiopia',
#   'score': '2',
#   'latitude': 11.9963,
#   'longitude': 41.225},
#  {'id': 77,
#   'name': 'South',
#   'country': 'Tanzania',
#   'score': '8b',
#   'latitude': -4.268828571428571,
#   'longitude': 36.563071428571426},
#  {'id': 77,
#   'name': 'South',
#   'country': 'Tanzania',
#   'score': '6a',
#   'latitude': -4.268828571428571,
#   'longitude': 36.563071428571426},
#  {'id': 77,
#   'name': 'South',
#   'country': 'Kenya',
#   'score': '8a',
#   'latitude': -4.268828571428571,
#   'longitude': 36.563071428571426},
#  {'id': 77,
#   'name': 'South',
#   'country': 'Tanzania',
#   'score': '6a',
#   'latitude': -4.268828571428571,
#   'longitude': 36.563071428571426},
#  {'id': 77,
#   'name': 'South',
#   'country': 'Tanzania',
#   'score': '5',
#   'latitude': -4.268828571428571,
#   'longitude': 36.563071428571426},
#  {'id': 77,
#   'name': 'South',
#   'country': 'Tanzania',
#   'score': '6b',
#   'latitude': -4.268828571428571,
#   'longitude': 36.563071428571426},
#  {'id': 77,
#   'name': 'South',
#   'country': 'Tanzania',
#   'score': 'x10',
#   'latitude': -4.268828571428571,
#   'longitude': 36.563071428571426},
#  {'id': 78,
#   'name': 'Aasáx',
#   'country': 'Tanzania',
#   'score': '8b',
#   'latitude': -4.0022,
#   'longitude': 36.8687},
#  {'id': 79,
#   'name': 'Albanian, Arvanitika',
#   'country': 'Greece',
#   'score': '7',
#   'latitude': 38.283,
#   'longitude': 23.3703},
#  {'id': 80,
#   'name': 'Abau',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -4.0435,
#   'longitude': 141.1828},
#  {'id': 81,
#   'name': 'Abau',
#   'country': 'Papua New Guinea',
#   'score': '5',
#   'latitude': -4.0435,
#   'longitude': 141.1828},
#  {'id': 82,
#   'name': 'North New Guinea',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': -5.257662857142857,
#   'longitude': 145.98938666666666},
#  {'id': 82,
#   'name': 'North New Guinea',
#   'country': 'Indonesia',
#   'score': '8a',
# ...
#   'score': '6a',
#   'latitude': -4.2386,
#   'longitude': 144.4958},
#  {'id': 272,
#   'name': 'Left Bank',
#   'country': 'Ghana',
#   'score': '5',
#   'latitude': 6.922726666666667,
#   'longitude': 1.5212366666666668},
#  {'id': 272,
#   'name': 'Left Bank',
#   'country': 'Benin',
#   'score': '6a',
#   'latitude': 6.922726666666667,
#   'longitude': 1.5212366666666668},
#  {'id': 272,
#   'name': 'Left Bank',
#   'country': 'Ghana',
#   'score': '5',
#   'latitude': 6.922726666666667,
#   'longitude': 1.5212366666666668},
#  {'id': 272,
#   'name': 'Left Bank',
#   'country': 'Ghana',
#   'score': '6a',
#   'latitude': 6.922726666666667,
#   'longitude': 1.5212366666666668},
#  {'id': 273,
#   'name': 'Kposo-Ahlo-Bowili',
#   'country': 'Ghana',
#   'score': '6b',
#   'latitude': 7.09515,
#   'longitude': 0.671025},
#  {'id': 273,
#   'name': 'Kposo-Ahlo-Bowili',
#   'country': 'Togo',
#   'score': '5',
#   'latitude': 7.09515,
#   'longitude': 0.671025},
#  {'id': 273,
#   'name': 'Kposo-Ahlo-Bowili',
#   'country': 'Ghana',
#   'score': '5',
#   'latitude': 7.09515,
#   'longitude': 0.671025},
#  {'id': 273,
#   'name': 'Kposo-Ahlo-Bowili',
#   'country': 'Togo',
#   'score': '5',
#   'latitude': 7.09515,
#   'longitude': 0.671025},
#  {'id': 274,
#   'name': 'Adangbe',
#   'country': 'Ghana',
#   'score': '6b',
#   'latitude': 6.3699,
#   'longitude': 0.7633},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Ghana',
#   'score': '6b',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Afghanistan',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'United States',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Australia',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Algeria',
#   'score': '6a',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Austria',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'United Kingdom',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Thailand',
#   'score': '6b',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Bulgaria',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Indonesia',
#   'score': '6b',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Bolivia',
#   'score': '6a',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Chad',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Spain',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Thailand',
#   'score': '8a',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Czech Republic',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Chile',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Croatia',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Netherlands',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Denmark',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Ecuador',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Egypt',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Estonia',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Ethiopia',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Canada',
#   'score': '6a',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Finland',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'France',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Finland',
#   'score': '8a',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Nepal',
#   'score': '8b',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Ghana',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Germany',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Greece',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Guinea',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'China–Hong Kong',
#   'score': '6a',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Hungary',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Iceland',
#   'score': '6b',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Canada',
#   'score': '8a',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Indonesia',
#   'score': '6a',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'India',
#   'score': '6a',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Italy',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Ireland',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Jamaica',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Japan',
#   'score': '6a',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Nepal',
#   'score': '6b',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Malaysia',
#   'score': '8a',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Libya',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Lithuania',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Latvia',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Trinidad and Tobago',
#   'score': '7',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Malta',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Mexico',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Mexico',
#   'score': '6a',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Madagascar',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Nicaragua',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Norway',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Nepal',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'New Zealand',
#   'score': '6b',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Papua New Guinea',
#   'score': '6a',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Colombia',
#   'score': '8b',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Malaysia',
#   'score': '8a',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Poland',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Portugal',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Paraguay',
#   'score': '6a',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Romania',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Solomon Islands',
#   'score': 'x10',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Russian Federation',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Belgium',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'South Africa',
#   'score': '6a',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Switzerland',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Sierra Leone',
#   'score': '6a',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Switzerland',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Singapore',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Albania',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Spain',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Switzerland',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Slovakia',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Sweden',
#   'score': '4',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Israel',
#   'score': '6a',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Tunisia',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'China–Taiwan',
#   'score': '4',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Mali',
#   'score': '6a',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Tanzania',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Uganda',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Uruguay',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Ukraine',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Brazil',
#   'score': '6a',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Belgium',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Spain',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Kenya',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Malaysia',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Morocco',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Australia',
#   'score': '6a',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Australia',
#   'score': '8b',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Serbia',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Zimbabwe',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 275,
#   'name': 'Sign language',
#   'country': 'Zambia',
#   'score': '5',
#   'latitude': 24.723988421052635,
#   'longitude': 23.52450315789474},
#  {'id': 276,
#   'name': 'Adamorobe Sign Language',
#   'country': 'Ghana',
#   'score': '6b',
#   'latitude': 5.834,
#   'longitude': -0.151},
#  {'id': 277,
#   'name': 'South-West',
#   'country': 'Australia',
#   'score': 'x10',
#   'latitude': -25.45099076923077,
#   'longitude': 124.33748307692306},
#  {'id': 277,
#   'name': 'South-West',
#   'country': 'Australia',
#   'score': '8b',
#   'latitude': -25.45099076923077,
#   'longitude': 124.33748307692306},
#  ...]

# %%
unique_nodes

# %%
with open("../data/ethno_links.json", "w") as outfile:
    json.dump(fin_json, outfile)
